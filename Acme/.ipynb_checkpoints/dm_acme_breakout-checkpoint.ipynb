# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)
logging.debug('Needed to run for Jupyter Notebook')
# Out:
# DEBUG:root:Needed to run for Jupyter Notebook

# %%
import acme

# %%
environment_library = 'gym'

# %%
import IPython

from acme import environment_loop
from acme import specs
from acme import wrappers
from acme.agents.tf import d4pg
from acme.tf import networks
from acme.tf import utils as tf2_utils
from acme.utils import loggers
import numpy as np
import sonnet as snt

from absl import app
from absl import flags
import acme
from acme.agents.tf import dqn
from acme.tf import networks

# Import the selected environment lib
if environment_library == 'dm_control':
  from dm_control import suite
elif environment_library == 'gym':
  import gym

# Imports required for visualization
import pyvirtualdisplay
import imageio
import base64

# Set up a virtual display for rendering.
display = pyvirtualdisplay.Display(visible=0, size=(1400, 900)).start()

# %%
# helper functions
import functools

from acme import wrappers
import dm_env
import gym

def make_environment(level: str, evaluation: bool = False) -> dm_env.Environment:
  env = gym.make(level, full_action_space=True)

  max_episode_len = 108_000 if evaluation else 50_000

  return wrappers.wrap_all(env, [
      wrappers.GymAtariAdapter,
      functools.partial(
          wrappers.AtariWrapper,
          to_float=True,
          max_episode_len=max_episode_len,
          zero_discount_on_life_loss=True,
      ),
      wrappers.SinglePrecisionWrapper,
  ])

# %%
# Create a simple helper function to render a frame from the current state of
# the environment.
def render(env):
    return env.environment.render(mode='rgb_array')

def display_video(frames, filename='temp.mp4'):
  """Save and display video."""

  # Write video
  with imageio.get_writer(filename, fps=60) as video:
    for frame in frames:
      video.append_data(frame)

  # Read video and display the video
  video = open(filename, 'rb').read()
  b64_video = base64.b64encode(video)
  video_tag = ('<video  width="320" height="240" controls alt="test" '
               'src="data:video/mp4;base64,{0}">').format(b64_video.decode())

  return IPython.display.HTML(video_tag)

# %%
environment = make_environment('BreakoutDeterministic-v4')
environment_spec = acme.make_environment_spec(environment)
network = networks.DQNAtariNetwork(environment_spec.actions.num_values)

# Create a logger for the agent and environment loop.
# agent_logger = loggers.TerminalLogger(label='agent')
env_loop_logger = loggers.TerminalLogger(label='env_loop')

# agent = dqn.DQN(environment_spec, network, logger=agent_logger)
agent = dqn.DQN(environment_spec, network)

# Create an loop connecting this agent to the environment created above.
env_loop = acme.EnvironmentLoop(
    environment, agent, logger=env_loop_logger)
# env_loop = acme.EnvironmentLoop(environment, agent)

# Run a `num_episodes` training episodes.
# Rerun this cell until the agent has learned the given task.
# env_loop.run(num_episodes=1000)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-6-dd9e4cf74864> in <module>
#       8
#       9 # agent = dqn.DQN(environment_spec, network, logger=agent_logger)
# ---> 10 agent = dqn.DQN(environment_spec, network)
#      11
#      12 # Create an loop connecting this agent to the environment created above.
#
# ~/anaconda3/envs/acme/lib/python3.8/site-packages/acme/agents/tf/dqn/agent.py in __init__(self, environment_spec, network, batch_size, prefetch_size, target_update_period, samples_per_insert, min_replay_size, max_replay_size, importance_sampling_exponent, priority_exponent, n_step, epsilon, learning_rate, discount, logger, checkpoint, checkpoint_subpath, policy_network, max_gradient_norm)
#     136
#     137     # Ensure that we create the variables before proceeding (maybe not needed).
# --> 138     tf2_utils.create_variables(network, [environment_spec.observations])
#     139     tf2_utils.create_variables(target_network, [environment_spec.observations])
#     140
#
# ~/anaconda3/envs/acme/lib/python3.8/site-packages/acme/tf/utils.py in create_variables(network, input_spec)
#     101
#     102   # Forward pass of the network which will create variables as a side effect.
# --> 103   dummy_output = network(*add_batch_dim(dummy_input))
#     104
#     105   # Evaluate the input signature by converting the dummy input into a
#
# ~/anaconda3/envs/acme/lib/python3.8/site-packages/sonnet/src/utils.py in _decorate_unbound_method(self, *args, **kwargs)
#      87       def _decorate_unbound_method(self, *args, **kwargs):
#      88         bound_method = f.__get__(self, self.__class__)  # pytype: disable=attribute-error
# ---> 89         return decorator_fn(bound_method, self, args, kwargs)
#      90
#      91       return _decorate_unbound_method
#
# ~/anaconda3/envs/acme/lib/python3.8/site-packages/sonnet/src/base.py in wrap_with_name_scope(method, instance, args, kwargs)
#     270     # snt.Module enters the module name scope for all methods. To disable this
#     271     # for a particular method annotate it with `@snt.no_name_scope`.
# --> 272     return method(*args, **kwargs)
#     273
#     274
#
# ~/anaconda3/envs/acme/lib/python3.8/site-packages/acme/tf/networks/atari.py in __call__(self, inputs)
#      68
#      69   def __call__(self, inputs: Images) -> QValues:
# ---> 70     return self._network(inputs)
#      71
#      72
#
# ~/anaconda3/envs/acme/lib/python3.8/site-packages/sonnet/src/utils.py in _decorate_unbound_method(self, *args, **kwargs)
#      87       def _decorate_unbound_method(self, *args, **kwargs):
#      88         bound_method = f.__get__(self, self.__class__)  # pytype: disable=attribute-error
# ---> 89         return decorator_fn(bound_method, self, args, kwargs)
#      90
#      91       return _decorate_unbound_method
#
# ~/anaconda3/envs/acme/lib/python3.8/site-packages/sonnet/src/base.py in wrap_with_name_scope(method, instance, args, kwargs)
#     270     # snt.Module enters the module name scope for all methods. To disable this
#     271     # for a particular method annotate it with `@snt.no_name_scope`.
# --> 272     return method(*args, **kwargs)
#     273
#     274
#
# ~/anaconda3/envs/acme/lib/python3.8/site-packages/sonnet/src/sequential.py in __call__(self, inputs, *args, **kwargs)
#      70       if i == 0:
#      71         # Pass additional arguments to the first layer.
# ---> 72         outputs = mod(outputs, *args, **kwargs)
#      73       else:
#      74         outputs = mod(outputs)
#
# ~/anaconda3/envs/acme/lib/python3.8/site-packages/sonnet/src/utils.py in _decorate_unbound_method(self, *args, **kwargs)
#      87       def _decorate_unbound_method(self, *args, **kwargs):
#      88         bound_method = f.__get__(self, self.__class__)  # pytype: disable=attribute-error
# ---> 89         return decorator_fn(bound_method, self, args, kwargs)
#      90
#      91       return _decorate_unbound_method
#
# ~/anaconda3/envs/acme/lib/python3.8/site-packages/sonnet/src/base.py in wrap_with_name_scope(method, instance, args, kwargs)
#     270     # snt.Module enters the module name scope for all methods. To disable this
#     271     # for a particular method annotate it with `@snt.no_name_scope`.
# --> 272     return method(*args, **kwargs)
#     273
#     274
#
# ~/anaconda3/envs/acme/lib/python3.8/site-packages/acme/tf/networks/atari.py in __call__(self, inputs)
#      51
#      52   def __call__(self, inputs: Images) -> tf.Tensor:
# ---> 53     return self._network(inputs)
#      54
#      55
#
# ~/anaconda3/envs/acme/lib/python3.8/site-packages/sonnet/src/utils.py in _decorate_unbound_method(self, *args, **kwargs)
#      87       def _decorate_unbound_method(self, *args, **kwargs):
#      88         bound_method = f.__get__(self, self.__class__)  # pytype: disable=attribute-error
# ---> 89         return decorator_fn(bound_method, self, args, kwargs)
#      90
#      91       return _decorate_unbound_method
#
# ~/anaconda3/envs/acme/lib/python3.8/site-packages/sonnet/src/base.py in wrap_with_name_scope(method, instance, args, kwargs)
#     270     # snt.Module enters the module name scope for all methods. To disable this
#     271     # for a particular method annotate it with `@snt.no_name_scope`.
# --> 272     return method(*args, **kwargs)
#     273
#     274
#
# ~/anaconda3/envs/acme/lib/python3.8/site-packages/sonnet/src/sequential.py in __call__(self, inputs, *args, **kwargs)
#      70       if i == 0:
#      71         # Pass additional arguments to the first layer.
# ---> 72         outputs = mod(outputs, *args, **kwargs)
#      73       else:
#      74         outputs = mod(outputs)
#
# ~/anaconda3/envs/acme/lib/python3.8/site-packages/sonnet/src/utils.py in _decorate_unbound_method(self, *args, **kwargs)
#      87       def _decorate_unbound_method(self, *args, **kwargs):
#      88         bound_method = f.__get__(self, self.__class__)  # pytype: disable=attribute-error
# ---> 89         return decorator_fn(bound_method, self, args, kwargs)
#      90
#      91       return _decorate_unbound_method
#
# ~/anaconda3/envs/acme/lib/python3.8/site-packages/sonnet/src/base.py in wrap_with_name_scope(method, instance, args, kwargs)
#     270     # snt.Module enters the module name scope for all methods. To disable this
#     271     # for a particular method annotate it with `@snt.no_name_scope`.
# --> 272     return method(*args, **kwargs)
#     273
#     274
#
# ~/anaconda3/envs/acme/lib/python3.8/site-packages/sonnet/src/conv.py in __call__(self, inputs)
#     120       inputs = tf.pad(inputs, self._padding)
#     121
# --> 122     outputs = tf.nn.convolution(
#     123         inputs,
#     124         self.w,
#
# ~/anaconda3/envs/acme/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/anaconda3/envs/acme/lib/python3.8/site-packages/tensorflow/python/ops/nn_ops.py in convolution_v2(input, filters, strides, padding, data_format, dilations, name)
#    1129     dilations=None,
#    1130     name=None):
# -> 1131   return convolution_internal(
#    1132       input,  # pylint: disable=redefined-builtin
#    1133       filters,
#
# ~/anaconda3/envs/acme/lib/python3.8/site-packages/tensorflow/python/ops/nn_ops.py in convolution_internal(input, filters, strides, padding, data_format, dilations, name, call_from_convolution, num_spatial_dims)
#    1259         op = conv1d
#    1260
# -> 1261       return op(
#    1262           input,
#    1263           filters,
#
# ~/anaconda3/envs/acme/lib/python3.8/site-packages/tensorflow/python/ops/nn_ops.py in _conv2d_expanded_batch(input, filters, strides, padding, data_format, dilations, name)
#    2713     # We avoid calling squeeze_batch_dims to reduce extra python function
#    2714     # call slowdown in eager mode.  This branch doesn't require reshapes.
# -> 2715     return gen_nn_ops.conv2d(
#    2716         input,
#    2717         filter=filters,
#
# ~/anaconda3/envs/acme/lib/python3.8/site-packages/tensorflow/python/ops/gen_nn_ops.py in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#     930       return _result
#     931     except _core._NotOkStatusException as e:
# --> 932       _ops.raise_from_not_ok_status(e, name)
#     933     except _core._FallbackException:
#     934       pass
#
# ~/anaconda3/envs/acme/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6939   message = e.message + (" name: " + name if name is not None else "")
#    6940   # pylint: disable=protected-access
# -> 6941   six.raise_from(core._status_to_exception(e.code, message), None)
#    6942   # pylint: enable=protected-access
#    6943
#
# ~/anaconda3/envs/acme/lib/python3.8/site-packages/six.py in raise_from(value, from_value)
#
# NotFoundError: No algorithm worked! [Op:Conv2D]

# %%
# Run a `num_episodes` training episodes.
# Rerun this cell until the agent has learned the given task.
env_loop.run(num_episodes=500)
# Out:
# INFO:root:[Learner] Loss = 0.251 | Steps = 21543 | Walltime = 5292.061
# INFO:root:[Learner] Loss = 0.161 | Steps = 21551 | Walltime = 5293.177
# INFO:root:[Learner] Loss = 0.215 | Steps = 21558 | Walltime = 5294.211
# INFO:root:[Learner] Loss = 0.209 | Steps = 21566 | Walltime = 5295.317
# INFO:root:[Learner] Loss = 0.154 | Steps = 21574 | Walltime = 5296.405
# INFO:root:[Env Loop] Episode Length = 256 | Episode Return = 30.0 | Episodes = 1001 | Steps = 173588 | Steps Per Second = 56.663
# INFO:root:[Learner] Loss = 0.215 | Steps = 21582 | Walltime = 5297.514
# INFO:root:[Learner] Loss = 0.155 | Steps = 21590 | Walltime = 5298.623
# INFO:root:[Env Loop] Episode Length = 173 | Episode Return = 16.0 | Episodes = 1002 | Steps = 173761 | Steps Per Second = 57.827
# INFO:root:[Learner] Loss = 0.201 | Steps = 21598 | Walltime = 5299.715
# INFO:root:[Learner] Loss = 0.192 | Steps = 21606 | Walltime = 5300.829
# INFO:root:[Learner] Loss = 0.158 | Steps = 21613 | Walltime = 5301.872
# INFO:root:[Learner] Loss = 0.164 | Steps = 21621 | Walltime = 5302.958
# INFO:root:[Env Loop] Episode Length = 258 | Episode Return = 35.0 | Episodes = 1003 | Steps = 174019 | Steps Per Second = 57.943
# INFO:root:[Learner] Loss = 0.182 | Steps = 21629 | Walltime = 5304.040
# INFO:root:[Learner] Loss = 0.178 | Steps = 21637 | Walltime = 5305.159
# INFO:root:[Learner] Loss = 0.102 | Steps = 21645 | Walltime = 5306.265
# INFO:root:[Learner] Loss = 0.240 | Steps = 21652 | Walltime = 5307.341
# INFO:root:[Env Loop] Episode Length = 225 | Episode Return = 35.0 | Episodes = 1004 | Steps = 174244 | Steps Per Second = 55.109
# INFO:root:[Learner] Loss = 0.207 | Steps = 21659 | Walltime = 5308.427
# INFO:root:[Learner] Loss = 0.215 | Steps = 21666 | Walltime = 5309.468
# INFO:root:[Learner] Loss = 0.136 | Steps = 21672 | Walltime = 5310.473
# INFO:root:[Learner] Loss = 0.183 | Steps = 21679 | Walltime = 5311.563
# INFO:root:[Learner] Loss = 0.201 | Steps = 21686 | Walltime = 5312.680
# INFO:root:[Env Loop] Episode Length = 266 | Episode Return = 24.0 | Episodes = 1005 | Steps = 174510 | Steps Per Second = 50.723
# INFO:root:[Learner] Loss = 0.224 | Steps = 21692 | Walltime = 5313.702
# INFO:root:[Learner] Loss = 0.223 | Steps = 21699 | Walltime = 5314.787
# INFO:root:[Learner] Loss = 0.246 | Steps = 21707 | Walltime = 5315.894
# INFO:root:[Learner] Loss = 0.211 | Steps = 21714 | Walltime = 5317.087
# INFO:root:[Learner] Loss = 0.231 | Steps = 21720 | Walltime = 5318.139
# INFO:root:[Env Loop] Episode Length = 268 | Episode Return = 38.0 | Episodes = 1006 | Steps = 174778 | Steps Per Second = 49.684
# INFO:root:[Learner] Loss = 0.178 | Steps = 21727 | Walltime = 5319.287
# INFO:root:[Learner] Loss = 0.256 | Steps = 21733 | Walltime = 5320.326
# INFO:root:[Learner] Loss = 0.221 | Steps = 21739 | Walltime = 5321.392
# INFO:root:[Learner] Loss = 0.168 | Steps = 21745 | Walltime = 5322.477
# INFO:root:[Learner] Loss = 0.205 | Steps = 21751 | Walltime = 5323.525
# INFO:root:[Env Loop] Episode Length = 233 | Episode Return = 27.0 | Episodes = 1007 | Steps = 175011 | Steps Per Second = 45.957
# INFO:root:[Learner] Loss = 0.192 | Steps = 21758 | Walltime = 5324.643
# INFO:root:[Learner] Loss = 0.221 | Steps = 21765 | Walltime = 5325.745
# INFO:root:[Learner] Loss = 0.173 | Steps = 21772 | Walltime = 5326.861
# INFO:root:[Learner] Loss = 0.232 | Steps = 21778 | Walltime = 5327.921
# INFO:root:[Learner] Loss = 0.202 | Steps = 21784 | Walltime = 5328.924
# INFO:root:[Env Loop] Episode Length = 257 | Episode Return = 31.0 | Episodes = 1008 | Steps = 175268 | Steps Per Second = 48.866
# INFO:root:[Learner] Loss = 0.246 | Steps = 21791 | Walltime = 5330.025
# INFO:root:[Learner] Loss = 0.205 | Steps = 21798 | Walltime = 5331.096
# INFO:root:[Learner] Loss = 0.233 | Steps = 21804 | Walltime = 5332.107
# INFO:root:[Env Loop] Episode Length = 192 | Episode Return = 24.0 | Episodes = 1009 | Steps = 175460 | Steps Per Second = 50.236
# INFO:root:[Learner] Loss = 0.205 | Steps = 21811 | Walltime = 5333.177
# INFO:root:[Learner] Loss = 0.238 | Steps = 21818 | Walltime = 5334.253
# INFO:root:[Learner] Loss = 0.268 | Steps = 21824 | Walltime = 5335.280
# INFO:root:[Learner] Loss = 0.234 | Steps = 21830 | Walltime = 5336.379
# INFO:root:[Env Loop] Episode Length = 199 | Episode Return = 23.0 | Episodes = 1010 | Steps = 175659 | Steps Per Second = 47.810
# INFO:root:[Learner] Loss = 0.223 | Steps = 21836 | Walltime = 5337.607
# INFO:root:[Learner] Loss = 0.156 | Steps = 21843 | Walltime = 5338.765
# INFO:root:[Env Loop] Episode Length = 122 | Episode Return = 10.0 | Episodes = 1011 | Steps = 175781 | Steps Per Second = 45.560
# INFO:root:[Learner] Loss = 0.196 | Steps = 21850 | Walltime = 5339.913
# INFO:root:[Learner] Loss = 0.210 | Steps = 21856 | Walltime = 5341.076
# INFO:root:[Learner] Loss = 0.161 | Steps = 21863 | Walltime = 5342.208
# INFO:root:[Learner] Loss = 0.155 | Steps = 21870 | Walltime = 5343.245
# INFO:root:[Env Loop] Episode Length = 189 | Episode Return = 20.0 | Episodes = 1012 | Steps = 175970 | Steps Per Second = 47.333
# INFO:root:[Learner] Loss = 0.193 | Steps = 21876 | Walltime = 5344.352
# INFO:root:[Learner] Loss = 0.192 | Steps = 21882 | Walltime = 5345.481
# INFO:root:[Learner] Loss = 0.204 | Steps = 21887 | Walltime = 5346.483
# INFO:root:[Learner] Loss = 0.155 | Steps = 21893 | Walltime = 5347.624
# INFO:root:[Learner] Loss = 0.167 | Steps = 21900 | Walltime = 5348.755
# INFO:root:[Learner] Loss = 0.201 | Steps = 21905 | Walltime = 5349.820
# INFO:root:[Env Loop] Episode Length = 304 | Episode Return = 38.0 | Episodes = 1013 | Steps = 176274 | Steps Per Second = 42.779
# INFO:root:[Learner] Loss = 0.188 | Steps = 21911 | Walltime = 5350.925
# INFO:root:[Learner] Loss = 0.167 | Steps = 21917 | Walltime = 5351.999
# INFO:root:[Learner] Loss = 0.188 | Steps = 21923 | Walltime = 5353.146
# INFO:root:[Learner] Loss = 0.209 | Steps = 21929 | Walltime = 5354.221
# INFO:root:[Learner] Loss = 0.235 | Steps = 21935 | Walltime = 5355.420
# INFO:root:[Env Loop] Episode Length = 243 | Episode Return = 30.0 | Episodes = 1014 | Steps = 176517 | Steps Per Second = 43.318
# INFO:root:[Learner] Loss = 0.120 | Steps = 21941 | Walltime = 5356.496
# INFO:root:[Learner] Loss = 0.228 | Steps = 21947 | Walltime = 5357.558
# INFO:root:[Learner] Loss = 0.211 | Steps = 21953 | Walltime = 5358.755
# INFO:root:[Learner] Loss = 0.248 | Steps = 21958 | Walltime = 5359.967
# INFO:root:[Learner] Loss = 0.251 | Steps = 21963 | Walltime = 5361.091
# INFO:root:[Learner] Loss = 0.184 | Steps = 21968 | Walltime = 5362.157
# INFO:root:[Learner] Loss = 0.207 | Steps = 21974 | Walltime = 5363.266
# INFO:root:[Env Loop] Episode Length = 291 | Episode Return = 43.0 | Episodes = 1015 | Steps = 176808 | Steps Per Second = 39.180
# INFO:root:[Learner] Loss = 0.308 | Steps = 21980 | Walltime = 5364.326
# INFO:root:[Learner] Loss = 0.189 | Steps = 21987 | Walltime = 5365.455
# INFO:root:[Learner] Loss = 0.174 | Steps = 21992 | Walltime = 5366.552
# INFO:root:[Learner] Loss = 0.198 | Steps = 21998 | Walltime = 5367.677
# INFO:root:[Env Loop] Episode Length = 182 | Episode Return = 17.0 | Episodes = 1016 | Steps = 176990 | Steps Per Second = 44.024
# INFO:root:[Learner] Loss = 0.233 | Steps = 22004 | Walltime = 5368.793
# INFO:root:[Learner] Loss = 0.228 | Steps = 22010 | Walltime = 5369.929
# INFO:root:[Env Loop] Episode Length = 128 | Episode Return = 11.0 | Episodes = 1017 | Steps = 177118 | Steps Per Second = 42.992
# INFO:root:[Learner] Loss = 0.198 | Steps = 22016 | Walltime = 5371.054
# INFO:root:[Learner] Loss = 0.246 | Steps = 22022 | Walltime = 5372.164
# INFO:root:[Learner] Loss = 0.199 | Steps = 22028 | Walltime = 5373.260
# INFO:root:[Learner] Loss = 0.141 | Steps = 22035 | Walltime = 5374.388
# INFO:root:[Env Loop] Episode Length = 179 | Episode Return = 19.0 | Episodes = 1018 | Steps = 177297 | Steps Per Second = 43.377
# INFO:root:[Learner] Loss = 0.158 | Steps = 22040 | Walltime = 5375.404
# INFO:root:[Learner] Loss = 0.147 | Steps = 22046 | Walltime = 5376.546
# INFO:root:[Learner] Loss = 0.144 | Steps = 22052 | Walltime = 5377.735
# INFO:root:[Env Loop] Episode Length = 158 | Episode Return = 16.0 | Episodes = 1019 | Steps = 177455 | Steps Per Second = 43.327
# INFO:root:[Learner] Loss = 0.279 | Steps = 22058 | Walltime = 5378.779
# INFO:root:[Learner] Loss = 0.274 | Steps = 22063 | Walltime = 5379.799
# INFO:root:[Learner] Loss = 0.234 | Steps = 22069 | Walltime = 5380.883
# INFO:root:[Learner] Loss = 0.199 | Steps = 22075 | Walltime = 5382.044
# INFO:root:[Learner] Loss = 0.200 | Steps = 22081 | Walltime = 5383.198
# INFO:root:[Learner] Loss = 0.239 | Steps = 22087 | Walltime = 5384.305
# INFO:root:[Learner] Loss = 0.210 | Steps = 22093 | Walltime = 5385.340
# INFO:root:[Env Loop] Episode Length = 285 | Episode Return = 35.0 | Episodes = 1020 | Steps = 177740 | Steps Per Second = 42.249
# INFO:root:[Learner] Loss = 0.313 | Steps = 22099 | Walltime = 5386.386
# INFO:root:[Learner] Loss = 0.152 | Steps = 22105 | Walltime = 5387.430
# INFO:root:[Learner] Loss = 0.319 | Steps = 22111 | Walltime = 5388.561
# INFO:root:[Learner] Loss = 0.216 | Steps = 22117 | Walltime = 5389.631
# INFO:root:[Env Loop] Episode Length = 234 | Episode Return = 35.0 | Episodes = 1021 | Steps = 177974 | Steps Per Second = 45.402
# INFO:root:[Learner] Loss = 0.162 | Steps = 22123 | Walltime = 5390.680
# INFO:root:[Learner] Loss = 0.190 | Steps = 22129 | Walltime = 5391.718
# INFO:root:[Learner] Loss = 0.142 | Steps = 22134 | Walltime = 5392.756
# INFO:root:[Learner] Loss = 0.323 | Steps = 22140 | Walltime = 5393.950
# INFO:root:[Learner] Loss = 0.254 | Steps = 22147 | Walltime = 5395.057
# INFO:root:[Env Loop] Episode Length = 229 | Episode Return = 23.0 | Episodes = 1022 | Steps = 178203 | Steps Per Second = 43.519
# INFO:root:[Learner] Loss = 0.209 | Steps = 22153 | Walltime = 5396.107
# INFO:root:[Learner] Loss = 0.272 | Steps = 22159 | Walltime = 5397.199
# INFO:root:[Learner] Loss = 0.251 | Steps = 22164 | Walltime = 5398.208
# INFO:root:[Learner] Loss = 0.243 | Steps = 22170 | Walltime = 5399.260
# INFO:root:[Env Loop] Episode Length = 162 | Episode Return = 21.0 | Episodes = 1023 | Steps = 178365 | Steps Per Second = 44.238
# INFO:root:[Learner] Loss = 0.219 | Steps = 22175 | Walltime = 5400.354
# INFO:root:[Learner] Loss = 0.103 | Steps = 22180 | Walltime = 5401.395
# INFO:root:[Learner] Loss = 0.193 | Steps = 22186 | Walltime = 5402.493
# INFO:root:[Learner] Loss = 0.178 | Steps = 22192 | Walltime = 5403.612
# INFO:root:[Env Loop] Episode Length = 195 | Episode Return = 19.0 | Episodes = 1024 | Steps = 178560 | Steps Per Second = 40.249
# INFO:root:[Learner] Loss = 0.213 | Steps = 22198 | Walltime = 5404.705
# INFO:root:[Learner] Loss = 0.247 | Steps = 22205 | Walltime = 5405.843
# INFO:root:[Learner] Loss = 0.203 | Steps = 22211 | Walltime = 5406.889
# INFO:root:[Learner] Loss = 0.224 | Steps = 22216 | Walltime = 5408.028
# INFO:root:[Env Loop] Episode Length = 178 | Episode Return = 21.0 | Episodes = 1025 | Steps = 178738 | Steps Per Second = 44.401
# INFO:root:[Learner] Loss = 0.192 | Steps = 22221 | Walltime = 5409.068
# INFO:root:[Learner] Loss = 0.202 | Steps = 22226 | Walltime = 5410.113
# INFO:root:[Learner] Loss = 0.221 | Steps = 22232 | Walltime = 5411.162
# INFO:root:[Env Loop] Episode Length = 119 | Episode Return = 10.0 | Episodes = 1026 | Steps = 178857 | Steps Per Second = 40.335
# INFO:root:[Learner] Loss = 0.228 | Steps = 22238 | Walltime = 5412.211
# INFO:root:[Learner] Loss = 0.214 | Steps = 22244 | Walltime = 5413.372
# INFO:root:[Learner] Loss = 0.228 | Steps = 22249 | Walltime = 5414.410
# INFO:root:[Env Loop] Episode Length = 170 | Episode Return = 13.0 | Episodes = 1027 | Steps = 179027 | Steps Per Second = 42.434
# INFO:root:[Learner] Loss = 0.210 | Steps = 22255 | Walltime = 5415.462
# INFO:root:[Learner] Loss = 0.161 | Steps = 22261 | Walltime = 5416.597
# INFO:root:[Learner] Loss = 0.279 | Steps = 22267 | Walltime = 5417.755
# INFO:root:[Learner] Loss = 0.245 | Steps = 22272 | Walltime = 5418.798
# INFO:root:[Learner] Loss = 0.222 | Steps = 22278 | Walltime = 5419.877
# INFO:root:[Env Loop] Episode Length = 210 | Episode Return = 19.0 | Episodes = 1028 | Steps = 179237 | Steps Per Second = 41.331
# INFO:root:[Learner] Loss = 0.185 | Steps = 22284 | Walltime = 5421.023
# INFO:root:[Learner] Loss = 0.109 | Steps = 22290 | Walltime = 5422.100
# INFO:root:[Learner] Loss = 0.280 | Steps = 22296 | Walltime = 5423.114
# INFO:root:[Learner] Loss = 0.188 | Steps = 22302 | Walltime = 5424.266
# INFO:root:[Env Loop] Episode Length = 176 | Episode Return = 22.0 | Episodes = 1029 | Steps = 179413 | Steps Per Second = 44.655
# INFO:root:[Learner] Loss = 0.253 | Steps = 22308 | Walltime = 5425.338
# INFO:root:[Learner] Loss = 0.218 | Steps = 22313 | Walltime = 5426.345
# INFO:root:[Learner] Loss = 0.251 | Steps = 22320 | Walltime = 5427.459
# INFO:root:[Learner] Loss = 0.281 | Steps = 22325 | Walltime = 5428.460
# INFO:root:[Env Loop] Episode Length = 204 | Episode Return = 22.0 | Episodes = 1030 | Steps = 179617 | Steps Per Second = 44.196
# INFO:root:[Learner] Loss = 0.186 | Steps = 22331 | Walltime = 5429.496
# INFO:root:[Learner] Loss = 0.139 | Steps = 22337 | Walltime = 5430.555
# INFO:root:[Learner] Loss = 0.181 | Steps = 22344 | Walltime = 5431.682
# INFO:root:[Learner] Loss = 0.188 | Steps = 22350 | Walltime = 5432.734
# INFO:root:[Learner] Loss = 0.165 | Steps = 22356 | Walltime = 5433.937
# INFO:root:[Env Loop] Episode Length = 240 | Episode Return = 30.0 | Episodes = 1031 | Steps = 179857 | Steps Per Second = 45.118
# INFO:root:[Learner] Loss = 0.196 | Steps = 22361 | Walltime = 5434.943
# INFO:root:[Learner] Loss = 0.220 | Steps = 22368 | Walltime = 5436.074
# INFO:root:[Learner] Loss = 0.195 | Steps = 22374 | Walltime = 5437.189
# INFO:root:[Learner] Loss = 0.176 | Steps = 22380 | Walltime = 5438.269
# INFO:root:[Learner] Loss = 0.206 | Steps = 22386 | Walltime = 5439.373
# INFO:root:[Env Loop] Episode Length = 223 | Episode Return = 28.0 | Episodes = 1032 | Steps = 180080 | Steps Per Second = 44.076
# INFO:root:[Learner] Loss = 0.187 | Steps = 22392 | Walltime = 5440.531
# INFO:root:[Learner] Loss = 0.237 | Steps = 22397 | Walltime = 5441.552
# INFO:root:[Learner] Loss = 0.172 | Steps = 22403 | Walltime = 5442.646
# INFO:root:[Env Loop] Episode Length = 167 | Episode Return = 16.0 | Episodes = 1033 | Steps = 180247 | Steps Per Second = 43.027
# INFO:root:[Learner] Loss = 0.154 | Steps = 22409 | Walltime = 5443.658
# INFO:root:[Learner] Loss = 0.198 | Steps = 22415 | Walltime = 5444.744
# INFO:root:[Learner] Loss = 0.210 | Steps = 22420 | Walltime = 5445.862
# INFO:root:[Learner] Loss = 0.241 | Steps = 22426 | Walltime = 5446.988
# INFO:root:[Learner] Loss = 0.201 | Steps = 22432 | Walltime = 5448.143
# INFO:root:[Learner] Loss = 0.241 | Steps = 22438 | Walltime = 5449.196
# INFO:root:[Env Loop] Episode Length = 256 | Episode Return = 26.0 | Episodes = 1034 | Steps = 180503 | Steps Per Second = 42.196
# INFO:root:[Learner] Loss = 0.230 | Steps = 22444 | Walltime = 5450.325
# INFO:root:[Learner] Loss = 0.226 | Steps = 22450 | Walltime = 5451.449
# INFO:root:[Learner] Loss = 0.172 | Steps = 22457 | Walltime = 5452.611
# INFO:root:[Learner] Loss = 0.170 | Steps = 22463 | Walltime = 5453.691
# INFO:root:[Env Loop] Episode Length = 223 | Episode Return = 31.0 | Episodes = 1035 | Steps = 180726 | Steps Per Second = 44.345
# INFO:root:[Learner] Loss = 0.248 | Steps = 22469 | Walltime = 5454.895
# INFO:root:[Learner] Loss = 0.213 | Steps = 22475 | Walltime = 5456.044
# INFO:root:[Learner] Loss = 0.231 | Steps = 22481 | Walltime = 5457.194
# INFO:root:[Env Loop] Episode Length = 119 | Episode Return = 9.0 | Episodes = 1036 | Steps = 180845 | Steps Per Second = 40.915
# INFO:root:[Learner] Loss = 0.190 | Steps = 22487 | Walltime = 5458.237
# INFO:root:[Learner] Loss = 0.197 | Steps = 22492 | Walltime = 5459.284
# INFO:root:[Learner] Loss = 0.154 | Steps = 22498 | Walltime = 5460.418
# INFO:root:[Learner] Loss = 0.219 | Steps = 22504 | Walltime = 5461.636
# INFO:root:[Env Loop] Episode Length = 183 | Episode Return = 18.0 | Episodes = 1037 | Steps = 181028 | Steps Per Second = 41.180
# INFO:root:[Learner] Loss = 0.284 | Steps = 22509 | Walltime = 5462.658
# INFO:root:[Learner] Loss = 0.227 | Steps = 22515 | Walltime = 5463.829
# INFO:root:[Learner] Loss = 0.209 | Steps = 22521 | Walltime = 5464.919
# INFO:root:[Learner] Loss = 0.128 | Steps = 22527 | Walltime = 5466.059
# INFO:root:[Env Loop] Episode Length = 222 | Episode Return = 30.0 | Episodes = 1038 | Steps = 181250 | Steps Per Second = 42.057
# INFO:root:[Learner] Loss = 0.120 | Steps = 22533 | Walltime = 5467.172
# INFO:root:[Learner] Loss = 0.195 | Steps = 22539 | Walltime = 5468.311
# INFO:root:[Learner] Loss = 0.237 | Steps = 22545 | Walltime = 5469.392
# INFO:root:[Learner] Loss = 0.192 | Steps = 22550 | Walltime = 5470.405
# INFO:root:[Env Loop] Episode Length = 170 | Episode Return = 17.0 | Episodes = 1039 | Steps = 181420 | Steps Per Second = 42.159
# INFO:root:[Learner] Loss = 0.164 | Steps = 22556 | Walltime = 5471.532
# INFO:root:[Learner] Loss = 0.182 | Steps = 22562 | Walltime = 5472.724
# INFO:root:[Learner] Loss = 0.234 | Steps = 22568 | Walltime = 5473.890
# INFO:root:[Learner] Loss = 0.167 | Steps = 22573 | Walltime = 5474.903
# INFO:root:[Env Loop] Episode Length = 166 | Episode Return = 17.0 | Episodes = 1040 | Steps = 181586 | Steps Per Second = 40.426
# INFO:root:[Learner] Loss = 0.217 | Steps = 22579 | Walltime = 5476.026
# INFO:root:[Learner] Loss = 0.193 | Steps = 22585 | Walltime = 5477.159
# INFO:root:[Learner] Loss = 0.141 | Steps = 22591 | Walltime = 5478.311
# INFO:root:[Learner] Loss = 0.279 | Steps = 22596 | Walltime = 5479.345
# INFO:root:[Learner] Loss = 0.161 | Steps = 22601 | Walltime = 5480.346
# INFO:root:[Env Loop] Episode Length = 231 | Episode Return = 23.0 | Episodes = 1041 | Steps = 181817 | Steps Per Second = 40.292
# INFO:root:[Learner] Loss = 0.197 | Steps = 22606 | Walltime = 5481.447
# INFO:root:[Learner] Loss = 0.196 | Steps = 22611 | Walltime = 5482.476
# INFO:root:[Learner] Loss = 0.191 | Steps = 22617 | Walltime = 5483.645
# INFO:root:[Learner] Loss = 0.208 | Steps = 22623 | Walltime = 5484.757
# INFO:root:[Learner] Loss = 0.205 | Steps = 22628 | Walltime = 5485.815
# INFO:root:[Learner] Loss = 0.235 | Steps = 22634 | Walltime = 5486.976
# INFO:root:[Env Loop] Episode Length = 253 | Episode Return = 30.0 | Episodes = 1042 | Steps = 182070 | Steps Per Second = 40.703
# INFO:root:[Learner] Loss = 0.261 | Steps = 22640 | Walltime = 5488.108
# INFO:root:[Learner] Loss = 0.248 | Steps = 22646 | Walltime = 5489.183
# INFO:root:[Learner] Loss = 0.183 | Steps = 22652 | Walltime = 5490.217
# INFO:root:[Learner] Loss = 0.213 | Steps = 22657 | Walltime = 5491.220
# INFO:root:[Env Loop] Episode Length = 200 | Episode Return = 13.0 | Episodes = 1043 | Steps = 182270 | Steps Per Second = 43.795
# INFO:root:[Learner] Loss = 0.221 | Steps = 22663 | Walltime = 5492.390
# INFO:root:[Learner] Loss = 0.159 | Steps = 22668 | Walltime = 5493.406
# INFO:root:[Learner] Loss = 0.231 | Steps = 22673 | Walltime = 5494.473
# INFO:root:[Learner] Loss = 0.260 | Steps = 22679 | Walltime = 5495.631
# INFO:root:[Learner] Loss = 0.240 | Steps = 22685 | Walltime = 5496.701
# INFO:root:[Env Loop] Episode Length = 226 | Episode Return = 25.0 | Episodes = 1044 | Steps = 182496 | Steps Per Second = 40.129
# INFO:root:[Learner] Loss = 0.211 | Steps = 22690 | Walltime = 5497.816
# INFO:root:[Learner] Loss = 0.200 | Steps = 22696 | Walltime = 5498.891
# INFO:root:[Learner] Loss = 0.156 | Steps = 22702 | Walltime = 5500.005
# INFO:root:[Env Loop] Episode Length = 118 | Episode Return = 9.0 | Episodes = 1045 | Steps = 182614 | Steps Per Second = 41.626
# INFO:root:[Learner] Loss = 0.180 | Steps = 22708 | Walltime = 5501.053
# INFO:root:[Learner] Loss = 0.203 | Steps = 22714 | Walltime = 5502.090
# INFO:root:[Learner] Loss = 0.206 | Steps = 22719 | Walltime = 5503.114
# INFO:root:[Learner] Loss = 0.155 | Steps = 22725 | Walltime = 5504.303
# INFO:root:[Learner] Loss = 0.157 | Steps = 22730 | Walltime = 5505.389
# INFO:root:[Env Loop] Episode Length = 262 | Episode Return = 34.0 | Episodes = 1046 | Steps = 182876 | Steps Per Second = 41.421
# INFO:root:[Learner] Loss = 0.152 | Steps = 22736 | Walltime = 5506.608
# INFO:root:[Learner] Loss = 0.227 | Steps = 22741 | Walltime = 5507.625
# INFO:root:[Learner] Loss = 0.229 | Steps = 22748 | Walltime = 5508.814
# INFO:root:[Learner] Loss = 0.182 | Steps = 22754 | Walltime = 5509.990
# INFO:root:[Learner] Loss = 0.198 | Steps = 22760 | Walltime = 5511.245
# INFO:root:[Learner] Loss = 0.143 | Steps = 22766 | Walltime = 5512.406
# INFO:root:[Env Loop] Episode Length = 267 | Episode Return = 38.0 | Episodes = 1047 | Steps = 183143 | Steps Per Second = 41.573
# INFO:root:[Learner] Loss = 0.208 | Steps = 22772 | Walltime = 5513.515
# INFO:root:[Learner] Loss = 0.253 | Steps = 22778 | Walltime = 5514.526
# INFO:root:[Learner] Loss = 0.190 | Steps = 22784 | Walltime = 5515.644
# INFO:root:[Learner] Loss = 0.255 | Steps = 22789 | Walltime = 5516.675
# INFO:root:[Env Loop] Episode Length = 183 | Episode Return = 16.0 | Episodes = 1048 | Steps = 183326 | Steps Per Second = 43.218
# INFO:root:[Learner] Loss = 0.173 | Steps = 22795 | Walltime = 5517.802
# INFO:root:[Learner] Loss = 0.182 | Steps = 22801 | Walltime = 5518.897
# INFO:root:[Learner] Loss = 0.309 | Steps = 22807 | Walltime = 5520.086
# INFO:root:[Learner] Loss = 0.184 | Steps = 22812 | Walltime = 5521.129
# INFO:root:[Env Loop] Episode Length = 177 | Episode Return = 15.0 | Episodes = 1049 | Steps = 183503 | Steps Per Second = 40.590
# INFO:root:[Learner] Loss = 0.208 | Steps = 22818 | Walltime = 5522.278
# INFO:root:[Learner] Loss = 0.183 | Steps = 22824 | Walltime = 5523.364
# INFO:root:[Env Loop] Episode Length = 117 | Episode Return = 8.0 | Episodes = 1050 | Steps = 183620 | Steps Per Second = 42.195
# INFO:root:[Learner] Loss = 0.122 | Steps = 22829 | Walltime = 5524.428
# INFO:root:[Learner] Loss = 0.234 | Steps = 22834 | Walltime = 5525.449
# INFO:root:[Learner] Loss = 0.113 | Steps = 22840 | Walltime = 5526.663
# INFO:root:[Env Loop] Episode Length = 130 | Episode Return = 10.0 | Episodes = 1051 | Steps = 183750 | Steps Per Second = 40.353
# INFO:root:[Learner] Loss = 0.209 | Steps = 22846 | Walltime = 5527.796
# INFO:root:[Learner] Loss = 0.215 | Steps = 22852 | Walltime = 5528.980
# INFO:root:[Env Loop] Episode Length = 91 | Episode Return = 6.0 | Episodes = 1052 | Steps = 183841 | Steps Per Second = 40.652
# INFO:root:[Learner] Loss = 0.169 | Steps = 22858 | Walltime = 5530.051
# INFO:root:[Learner] Loss = 0.230 | Steps = 22863 | Walltime = 5531.133
# INFO:root:[Learner] Loss = 0.215 | Steps = 22869 | Walltime = 5532.271
# INFO:root:[Learner] Loss = 0.248 | Steps = 22875 | Walltime = 5533.409
# INFO:root:[Learner] Loss = 0.257 | Steps = 22881 | Walltime = 5534.626
# INFO:root:[Env Loop] Episode Length = 247 | Episode Return = 29.0 | Episodes = 1053 | Steps = 184088 | Steps Per Second = 42.318
# INFO:root:[Learner] Loss = 0.182 | Steps = 22888 | Walltime = 5535.801
# INFO:root:[Learner] Loss = 0.217 | Steps = 22894 | Walltime = 5536.999
# INFO:root:[Learner] Loss = 0.216 | Steps = 22899 | Walltime = 5538.048
# INFO:root:[Learner] Loss = 0.263 | Steps = 22905 | Walltime = 5539.085
# INFO:root:[Learner] Loss = 0.219 | Steps = 22911 | Walltime = 5540.303
# INFO:root:[Learner] Loss = 0.215 | Steps = 22917 | Walltime = 5541.305
# INFO:root:[Env Loop] Episode Length = 270 | Episode Return = 36.0 | Episodes = 1054 | Steps = 184358 | Steps Per Second = 42.267
# INFO:root:[Learner] Loss = 0.259 | Steps = 22923 | Walltime = 5542.424
# INFO:root:[Learner] Loss = 0.194 | Steps = 22928 | Walltime = 5543.529
# INFO:root:[Learner] Loss = 0.166 | Steps = 22934 | Walltime = 5544.731
# INFO:root:[Learner] Loss = 0.215 | Steps = 22941 | Walltime = 5545.898
# INFO:root:[Learner] Loss = 0.243 | Steps = 22947 | Walltime = 5546.975
# INFO:root:[Learner] Loss = 0.229 | Steps = 22953 | Walltime = 5548.070
# INFO:root:[Env Loop] Episode Length = 264 | Episode Return = 37.0 | Episodes = 1055 | Steps = 184622 | Steps Per Second = 42.589
# INFO:root:[Learner] Loss = 0.180 | Steps = 22959 | Walltime = 5549.174
# INFO:root:[Learner] Loss = 0.213 | Steps = 22966 | Walltime = 5550.361
# INFO:root:[Learner] Loss = 0.142 | Steps = 22971 | Walltime = 5551.409
# INFO:root:[Env Loop] Episode Length = 170 | Episode Return = 17.0 | Episodes = 1056 | Steps = 184792 | Steps Per Second = 42.435
# INFO:root:[Learner] Loss = 0.178 | Steps = 22976 | Walltime = 5552.411
# INFO:root:[Learner] Loss = 0.170 | Steps = 22982 | Walltime = 5553.536
# INFO:root:[Learner] Loss = 0.164 | Steps = 22987 | Walltime = 5554.561
# INFO:root:[Learner] Loss = 0.213 | Steps = 22993 | Walltime = 5555.699
# INFO:root:[Learner] Loss = 0.204 | Steps = 22999 | Walltime = 5556.827
# INFO:root:[Env Loop] Episode Length = 198 | Episode Return = 17.0 | Episodes = 1057 | Steps = 184990 | Steps Per Second = 41.416
# INFO:root:[Learner] Loss = 0.260 | Steps = 23004 | Walltime = 5557.863
# INFO:root:[Learner] Loss = 0.183 | Steps = 23010 | Walltime = 5558.963
# INFO:root:[Learner] Loss = 0.150 | Steps = 23015 | Walltime = 5559.992
# INFO:root:[Learner] Loss = 0.296 | Steps = 23020 | Walltime = 5561.020
# INFO:root:[Learner] Loss = 0.168 | Steps = 23025 | Walltime = 5562.036
# INFO:root:[Env Loop] Episode Length = 247 | Episode Return = 37.0 | Episodes = 1058 | Steps = 185237 | Steps Per Second = 41.190
# INFO:root:[Learner] Loss = 0.197 | Steps = 23031 | Walltime = 5563.096
# INFO:root:[Learner] Loss = 0.175 | Steps = 23036 | Walltime = 5564.129
# INFO:root:[Learner] Loss = 0.271 | Steps = 23042 | Walltime = 5565.244
# INFO:root:[Learner] Loss = 0.224 | Steps = 23047 | Walltime = 5566.249
# INFO:root:[Learner] Loss = 0.190 | Steps = 23053 | Walltime = 5567.284
# INFO:root:[Env Loop] Episode Length = 203 | Episode Return = 21.0 | Episodes = 1059 | Steps = 185440 | Steps Per Second = 41.782
# INFO:root:[Learner] Loss = 0.211 | Steps = 23059 | Walltime = 5568.401
# INFO:root:[Learner] Loss = 0.185 | Steps = 23064 | Walltime = 5569.432
# INFO:root:[Learner] Loss = 0.174 | Steps = 23070 | Walltime = 5570.625
# INFO:root:[Learner] Loss = 0.261 | Steps = 23076 | Walltime = 5571.787
# INFO:root:[Env Loop] Episode Length = 197 | Episode Return = 22.0 | Episodes = 1060 | Steps = 185637 | Steps Per Second = 39.946
# INFO:root:[Learner] Loss = 0.149 | Steps = 23081 | Walltime = 5572.882
# INFO:root:[Learner] Loss = 0.179 | Steps = 23087 | Walltime = 5574.026
# INFO:root:[Learner] Loss = 0.217 | Steps = 23092 | Walltime = 5575.030
# INFO:root:[Learner] Loss = 0.150 | Steps = 23097 | Walltime = 5576.074
# INFO:root:[Learner] Loss = 0.220 | Steps = 23102 | Walltime = 5577.104
# INFO:root:[Learner] Loss = 0.177 | Steps = 23107 | Walltime = 5578.222
# INFO:root:[Env Loop] Episode Length = 251 | Episode Return = 33.0 | Episodes = 1061 | Steps = 185888 | Steps Per Second = 39.300
# INFO:root:[Learner] Loss = 0.157 | Steps = 23113 | Walltime = 5579.385
# INFO:root:[Learner] Loss = 0.229 | Steps = 23119 | Walltime = 5580.488
# INFO:root:[Learner] Loss = 0.181 | Steps = 23125 | Walltime = 5581.610
# INFO:root:[Learner] Loss = 0.247 | Steps = 23130 | Walltime = 5582.611
# INFO:root:[Learner] Loss = 0.300 | Steps = 23136 | Walltime = 5583.742
# INFO:root:[Learner] Loss = 0.156 | Steps = 23142 | Walltime = 5584.797
# INFO:root:[Env Loop] Episode Length = 243 | Episode Return = 31.0 | Episodes = 1062 | Steps = 186131 | Steps Per Second = 42.436
# INFO:root:[Learner] Loss = 0.238 | Steps = 23148 | Walltime = 5585.957
# INFO:root:[Learner] Loss = 0.144 | Steps = 23154 | Walltime = 5587.079
# INFO:root:[Learner] Loss = 0.198 | Steps = 23160 | Walltime = 5588.277
# INFO:root:[Env Loop] Episode Length = 173 | Episode Return = 19.0 | Episodes = 1063 | Steps = 186304 | Steps Per Second = 42.195
# INFO:root:[Learner] Loss = 0.195 | Steps = 23166 | Walltime = 5589.446
# INFO:root:[Learner] Loss = 0.259 | Steps = 23172 | Walltime = 5590.661
# INFO:root:[Learner] Loss = 0.291 | Steps = 23177 | Walltime = 5591.698
# INFO:root:[Learner] Loss = 0.197 | Steps = 23183 | Walltime = 5592.894
# INFO:root:[Learner] Loss = 0.214 | Steps = 23188 | Walltime = 5593.925
# INFO:root:[Learner] Loss = 0.189 | Steps = 23193 | Walltime = 5594.927
# INFO:root:[Env Loop] Episode Length = 243 | Episode Return = 18.0 | Episodes = 1064 | Steps = 186547 | Steps Per Second = 39.303
# INFO:root:[Learner] Loss = 0.168 | Steps = 23199 | Walltime = 5596.071
# INFO:root:[Learner] Loss = 0.243 | Steps = 23205 | Walltime = 5597.219
# INFO:root:[Learner] Loss = 0.245 | Steps = 23211 | Walltime = 5598.343
# INFO:root:[Env Loop] Episode Length = 151 | Episode Return = 13.0 | Episodes = 1065 | Steps = 186698 | Steps Per Second = 42.828
# INFO:root:[Learner] Loss = 0.238 | Steps = 23217 | Walltime = 5599.517
# INFO:root:[Learner] Loss = 0.202 | Steps = 23223 | Walltime = 5600.687
# INFO:root:[Learner] Loss = 0.191 | Steps = 23228 | Walltime = 5601.757
# INFO:root:[Env Loop] Episode Length = 130 | Episode Return = 11.0 | Episodes = 1066 | Steps = 186828 | Steps Per Second = 39.294
# INFO:root:[Learner] Loss = 0.270 | Steps = 23233 | Walltime = 5602.758
# INFO:root:[Learner] Loss = 0.141 | Steps = 23238 | Walltime = 5603.769
# INFO:root:[Learner] Loss = 0.203 | Steps = 23244 | Walltime = 5604.864
# INFO:root:[Learner] Loss = 0.271 | Steps = 23250 | Walltime = 5605.966
# INFO:root:[Learner] Loss = 0.220 | Steps = 23257 | Walltime = 5607.201
# INFO:root:[Env Loop] Episode Length = 242 | Episode Return = 29.0 | Episodes = 1067 | Steps = 187070 | Steps Per Second = 42.273
# INFO:root:[Learner] Loss = 0.223 | Steps = 23262 | Walltime = 5608.235
# INFO:root:[Learner] Loss = 0.249 | Steps = 23267 | Walltime = 5609.310
# INFO:root:[Learner] Loss = 0.213 | Steps = 23273 | Walltime = 5610.453
# INFO:root:[Learner] Loss = 0.256 | Steps = 23278 | Walltime = 5611.482
# INFO:root:[Learner] Loss = 0.191 | Steps = 23284 | Walltime = 5612.570
# INFO:root:[Env Loop] Episode Length = 198 | Episode Return = 26.0 | Episodes = 1068 | Steps = 187268 | Steps Per Second = 40.278
# INFO:root:[Learner] Loss = 0.196 | Steps = 23290 | Walltime = 5613.727
# INFO:root:[Learner] Loss = 0.236 | Steps = 23296 | Walltime = 5614.899
# INFO:root:[Learner] Loss = 0.207 | Steps = 23302 | Walltime = 5615.986
# INFO:root:[Learner] Loss = 0.255 | Steps = 23307 | Walltime = 5617.016
# INFO:root:[Learner] Loss = 0.245 | Steps = 23313 | Walltime = 5618.085
# INFO:root:[Env Loop] Episode Length = 229 | Episode Return = 26.0 | Episodes = 1069 | Steps = 187497 | Steps Per Second = 42.004
# INFO:root:[Learner] Loss = 0.219 | Steps = 23319 | Walltime = 5619.316
# INFO:root:[Learner] Loss = 0.246 | Steps = 23325 | Walltime = 5620.379
# INFO:root:[Learner] Loss = 0.195 | Steps = 23330 | Walltime = 5621.413
# INFO:root:[Learner] Loss = 0.289 | Steps = 23336 | Walltime = 5622.448
# INFO:root:[Env Loop] Episode Length = 204 | Episode Return = 26.0 | Episodes = 1070 | Steps = 187701 | Steps Per Second = 42.773
# INFO:root:[Learner] Loss = 0.223 | Steps = 23341 | Walltime = 5623.471
# INFO:root:[Learner] Loss = 0.246 | Steps = 23347 | Walltime = 5624.480
# INFO:root:[Learner] Loss = 0.173 | Steps = 23353 | Walltime = 5625.617
# INFO:root:[Learner] Loss = 0.208 | Steps = 23359 | Walltime = 5626.712
# INFO:root:[Learner] Loss = 0.204 | Steps = 23365 | Walltime = 5627.740
# INFO:root:[Env Loop] Episode Length = 241 | Episode Return = 22.0 | Episodes = 1071 | Steps = 187942 | Steps Per Second = 43.521
# INFO:root:[Learner] Loss = 0.248 | Steps = 23370 | Walltime = 5628.759
# INFO:root:[Learner] Loss = 0.277 | Steps = 23376 | Walltime = 5629.945
# INFO:root:[Learner] Loss = 0.326 | Steps = 23381 | Walltime = 5630.962
# INFO:root:[Learner] Loss = 0.188 | Steps = 23387 | Walltime = 5632.190
# INFO:root:[Learner] Loss = 0.215 | Steps = 23393 | Walltime = 5633.317
# INFO:root:[Learner] Loss = 0.149 | Steps = 23399 | Walltime = 5634.508
# INFO:root:[Learner] Loss = 0.256 | Steps = 23405 | Walltime = 5635.587
# INFO:root:[Env Loop] Episode Length = 292 | Episode Return = 36.0 | Episodes = 1072 | Steps = 188234 | Steps Per Second = 40.494
# INFO:root:[Learner] Loss = 0.205 | Steps = 23411 | Walltime = 5636.841
# INFO:root:[Learner] Loss = 0.196 | Steps = 23416 | Walltime = 5637.974
# INFO:root:[Learner] Loss = 0.242 | Steps = 23422 | Walltime = 5639.170
# INFO:root:[Learner] Loss = 0.168 | Steps = 23428 | Walltime = 5640.362
# INFO:root:[Env Loop] Episode Length = 225 | Episode Return = 38.0 | Episodes = 1073 | Steps = 188459 | Steps Per Second = 40.093
# INFO:root:[Learner] Loss = 0.189 | Steps = 23434 | Walltime = 5641.459
# INFO:root:[Learner] Loss = 0.252 | Steps = 23439 | Walltime = 5642.502
# INFO:root:[Learner] Loss = 0.222 | Steps = 23445 | Walltime = 5643.579
# INFO:root:[Learner] Loss = 0.221 | Steps = 23450 | Walltime = 5644.585
# INFO:root:[Learner] Loss = 0.204 | Steps = 23456 | Walltime = 5645.652
# INFO:root:[Env Loop] Episode Length = 199 | Episode Return = 18.0 | Episodes = 1074 | Steps = 188658 | Steps Per Second = 41.318
# INFO:root:[Learner] Loss = 0.267 | Steps = 23462 | Walltime = 5646.702
# INFO:root:[Learner] Loss = 0.204 | Steps = 23467 | Walltime = 5647.783
# INFO:root:[Env Loop] Episode Length = 77 | Episode Return = 5.0 | Episodes = 1075 | Steps = 188735 | Steps Per Second = 41.716
# INFO:root:[Learner] Loss = 0.261 | Steps = 23473 | Walltime = 5648.883
# INFO:root:[Learner] Loss = 0.129 | Steps = 23478 | Walltime = 5649.986
# INFO:root:[Env Loop] Episode Length = 115 | Episode Return = 9.0 | Episodes = 1076 | Steps = 188850 | Steps Per Second = 39.422
# INFO:root:[Learner] Loss = 0.201 | Steps = 23483 | Walltime = 5651.009
# INFO:root:[Learner] Loss = 0.239 | Steps = 23488 | Walltime = 5652.055
# INFO:root:[Learner] Loss = 0.252 | Steps = 23493 | Walltime = 5653.110
# INFO:root:[Learner] Loss = 0.185 | Steps = 23498 | Walltime = 5654.137
# INFO:root:[Learner] Loss = 0.275 | Steps = 23503 | Walltime = 5655.246
# INFO:root:[Env Loop] Episode Length = 214 | Episode Return = 21.0 | Episodes = 1077 | Steps = 189064 | Steps Per Second = 39.776
# INFO:root:[Learner] Loss = 0.215 | Steps = 23510 | Walltime = 5656.469
# INFO:root:[Learner] Loss = 0.224 | Steps = 23516 | Walltime = 5657.638
# INFO:root:[Learner] Loss = 0.173 | Steps = 23522 | Walltime = 5658.822
# INFO:root:[Learner] Loss = 0.214 | Steps = 23527 | Walltime = 5659.991
# INFO:root:[Learner] Loss = 0.324 | Steps = 23532 | Walltime = 5661.054
# INFO:root:[Learner] Loss = 0.250 | Steps = 23538 | Walltime = 5662.190
# INFO:root:[Env Loop] Episode Length = 254 | Episode Return = 22.0 | Episodes = 1078 | Steps = 189318 | Steps Per Second = 39.513
# INFO:root:[Learner] Loss = 0.274 | Steps = 23544 | Walltime = 5663.357
# INFO:root:[Learner] Loss = 0.317 | Steps = 23550 | Walltime = 5664.450
# INFO:root:[Learner] Loss = 0.177 | Steps = 23556 | Walltime = 5665.504
# INFO:root:[Learner] Loss = 0.199 | Steps = 23562 | Walltime = 5666.578
# INFO:root:[Learner] Loss = 0.233 | Steps = 23568 | Walltime = 5667.585
# INFO:root:[Env Loop] Episode Length = 235 | Episode Return = 29.0 | Episodes = 1079 | Steps = 189553 | Steps Per Second = 44.786
# INFO:root:[Learner] Loss = 0.229 | Steps = 23575 | Walltime = 5668.727
# INFO:root:[Learner] Loss = 0.267 | Steps = 23582 | Walltime = 5669.875
# INFO:root:[Learner] Loss = 0.230 | Steps = 23588 | Walltime = 5671.065
# INFO:root:[Learner] Loss = 0.207 | Steps = 23593 | Walltime = 5672.080
# INFO:root:[Learner] Loss = 0.230 | Steps = 23599 | Walltime = 5673.164
# INFO:root:[Env Loop] Episode Length = 235 | Episode Return = 33.0 | Episodes = 1080 | Steps = 189788 | Steps Per Second = 43.880
# INFO:root:[Learner] Loss = 0.243 | Steps = 23604 | Walltime = 5674.291
# INFO:root:[Learner] Loss = 0.339 | Steps = 23610 | Walltime = 5675.390
# INFO:root:[Learner] Loss = 0.220 | Steps = 23617 | Walltime = 5676.512
# INFO:root:[Learner] Loss = 0.251 | Steps = 23622 | Walltime = 5677.519
# INFO:root:[Learner] Loss = 0.280 | Steps = 23628 | Walltime = 5678.544
# INFO:root:[Env Loop] Episode Length = 233 | Episode Return = 31.0 | Episodes = 1081 | Steps = 190021 | Steps Per Second = 43.408
# INFO:root:[Learner] Loss = 0.165 | Steps = 23634 | Walltime = 5679.688
# INFO:root:[Learner] Loss = 0.203 | Steps = 23640 | Walltime = 5680.843
# INFO:root:[Learner] Loss = 0.235 | Steps = 23646 | Walltime = 5681.857
# INFO:root:[Learner] Loss = 0.276 | Steps = 23651 | Walltime = 5682.965
# INFO:root:[Learner] Loss = 0.230 | Steps = 23657 | Walltime = 5684.074
# INFO:root:[Env Loop] Episode Length = 256 | Episode Return = 37.0 | Episodes = 1082 | Steps = 190277 | Steps Per Second = 42.944
# INFO:root:[Learner] Loss = 0.195 | Steps = 23664 | Walltime = 5685.164
# INFO:root:[Learner] Loss = 0.274 | Steps = 23671 | Walltime = 5686.321
# INFO:root:[Learner] Loss = 0.228 | Steps = 23677 | Walltime = 5687.501
# INFO:root:[Env Loop] Episode Length = 160 | Episode Return = 18.0 | Episodes = 1083 | Steps = 190437 | Steps Per Second = 44.936
# INFO:root:[Learner] Loss = 0.274 | Steps = 23683 | Walltime = 5688.684
# INFO:root:[Learner] Loss = 0.146 | Steps = 23689 | Walltime = 5689.878
# INFO:root:[Learner] Loss = 0.252 | Steps = 23694 | Walltime = 5690.939
# INFO:root:[Env Loop] Episode Length = 122 | Episode Return = 10.0 | Episodes = 1084 | Steps = 190559 | Steps Per Second = 39.241
# INFO:root:[Learner] Loss = 0.218 | Steps = 23700 | Walltime = 5692.110
# INFO:root:[Learner] Loss = 0.228 | Steps = 23706 | Walltime = 5693.243
# INFO:root:[Learner] Loss = 0.247 | Steps = 23712 | Walltime = 5694.268
# INFO:root:[Env Loop] Episode Length = 138 | Episode Return = 11.0 | Episodes = 1085 | Steps = 190697 | Steps Per Second = 43.059
# INFO:root:[Learner] Loss = 0.273 | Steps = 23718 | Walltime = 5695.413
# INFO:root:[Learner] Loss = 0.244 | Steps = 23724 | Walltime = 5696.487
# INFO:root:[Env Loop] Episode Length = 103 | Episode Return = 9.0 | Episodes = 1086 | Steps = 190800 | Steps Per Second = 42.417
# INFO:root:[Learner] Loss = 0.237 | Steps = 23729 | Walltime = 5697.588
# INFO:root:[Learner] Loss = 0.196 | Steps = 23736 | Walltime = 5698.802
# INFO:root:[Learner] Loss = 0.217 | Steps = 23743 | Walltime = 5699.995
# INFO:root:[Learner] Loss = 0.131 | Steps = 23749 | Walltime = 5701.161
# INFO:root:[Learner] Loss = 0.238 | Steps = 23755 | Walltime = 5702.273
# INFO:root:[Env Loop] Episode Length = 245 | Episode Return = 37.0 | Episodes = 1087 | Steps = 191045 | Steps Per Second = 43.130
# INFO:root:[Learner] Loss = 0.141 | Steps = 23760 | Walltime = 5703.310
# INFO:root:[Learner] Loss = 0.226 | Steps = 23765 | Walltime = 5704.459
# INFO:root:[Learner] Loss = 0.189 | Steps = 23771 | Walltime = 5705.658
# INFO:root:[Learner] Loss = 0.247 | Steps = 23777 | Walltime = 5706.842
# INFO:root:[Learner] Loss = 0.238 | Steps = 23782 | Walltime = 5707.965
# INFO:root:[Learner] Loss = 0.167 | Steps = 23787 | Walltime = 5708.975
# INFO:root:[Env Loop] Episode Length = 259 | Episode Return = 17.0 | Episodes = 1088 | Steps = 191304 | Steps Per Second = 37.899
# INFO:root:[Learner] Loss = 0.267 | Steps = 23792 | Walltime = 5710.098
# INFO:root:[Learner] Loss = 0.241 | Steps = 23797 | Walltime = 5711.121
# INFO:root:[Learner] Loss = 0.234 | Steps = 23802 | Walltime = 5712.225
# INFO:root:[Learner] Loss = 0.249 | Steps = 23808 | Walltime = 5713.394
# INFO:root:[Env Loop] Episode Length = 171 | Episode Return = 16.0 | Episodes = 1089 | Steps = 191475 | Steps Per Second = 39.417
# INFO:root:[Learner] Loss = 0.204 | Steps = 23815 | Walltime = 5714.519
# INFO:root:[Learner] Loss = 0.155 | Steps = 23820 | Walltime = 5715.544
# INFO:root:[Learner] Loss = 0.173 | Steps = 23826 | Walltime = 5716.623
# INFO:root:[Learner] Loss = 0.231 | Steps = 23831 | Walltime = 5717.676
# INFO:root:[Env Loop] Episode Length = 205 | Episode Return = 20.0 | Episodes = 1090 | Steps = 191680 | Steps Per Second = 42.586
# INFO:root:[Learner] Loss = 0.299 | Steps = 23837 | Walltime = 5718.763
# INFO:root:[Learner] Loss = 0.201 | Steps = 23843 | Walltime = 5719.831
# INFO:root:[Learner] Loss = 0.249 | Steps = 23849 | Walltime = 5720.956
# INFO:root:[Learner] Loss = 0.219 | Steps = 23854 | Walltime = 5722.014
# INFO:root:[Learner] Loss = 0.197 | Steps = 23859 | Walltime = 5723.032
# INFO:root:[Env Loop] Episode Length = 222 | Episode Return = 20.0 | Episodes = 1091 | Steps = 191902 | Steps Per Second = 41.996
# INFO:root:[Learner] Loss = 0.290 | Steps = 23865 | Walltime = 5724.154
# INFO:root:[Learner] Loss = 0.222 | Steps = 23871 | Walltime = 5725.304
# INFO:root:[Learner] Loss = 0.175 | Steps = 23877 | Walltime = 5726.336
# INFO:root:[Learner] Loss = 0.257 | Steps = 23882 | Walltime = 5727.439
# INFO:root:[Env Loop] Episode Length = 150 | Episode Return = 14.0 | Episodes = 1092 | Steps = 192052 | Steps Per Second = 41.049
# INFO:root:[Learner] Loss = 0.153 | Steps = 23888 | Walltime = 5728.602
# INFO:root:[Learner] Loss = 0.223 | Steps = 23893 | Walltime = 5729.660
# INFO:root:[Learner] Loss = 0.223 | Steps = 23898 | Walltime = 5730.685
# INFO:root:[Learner] Loss = 0.213 | Steps = 23904 | Walltime = 5731.798
# INFO:root:[Learner] Loss = 0.215 | Steps = 23910 | Walltime = 5732.968
# INFO:root:[Learner] Loss = 0.256 | Steps = 23916 | Walltime = 5734.025
# INFO:root:[Env Loop] Episode Length = 287 | Episode Return = 33.0 | Episodes = 1093 | Steps = 192339 | Steps Per Second = 41.484
# INFO:root:[Learner] Loss = 0.218 | Steps = 23922 | Walltime = 5735.190
# INFO:root:[Learner] Loss = 0.148 | Steps = 23928 | Walltime = 5736.302
# INFO:root:[Learner] Loss = 0.226 | Steps = 23934 | Walltime = 5737.372
# INFO:root:[Env Loop] Episode Length = 154 | Episode Return = 16.0 | Episodes = 1094 | Steps = 192493 | Steps Per Second = 43.897
# INFO:root:[Learner] Loss = 0.164 | Steps = 23940 | Walltime = 5738.458
# INFO:root:[Learner] Loss = 0.163 | Steps = 23945 | Walltime = 5739.475
# INFO:root:[Learner] Loss = 0.207 | Steps = 23950 | Walltime = 5740.508
# INFO:root:[Learner] Loss = 0.226 | Steps = 23956 | Walltime = 5741.559
# INFO:root:[Env Loop] Episode Length = 194 | Episode Return = 20.0 | Episodes = 1095 | Steps = 192687 | Steps Per Second = 41.887
# INFO:root:[Learner] Loss = 0.203 | Steps = 23962 | Walltime = 5742.703
# INFO:root:[Learner] Loss = 0.141 | Steps = 23968 | Walltime = 5743.854
# INFO:root:[Learner] Loss = 0.292 | Steps = 23974 | Walltime = 5744.966
# INFO:root:[Learner] Loss = 0.148 | Steps = 23980 | Walltime = 5746.093
# INFO:root:[Learner] Loss = 0.201 | Steps = 23986 | Walltime = 5747.227
# INFO:root:[Learner] Loss = 0.137 | Steps = 23991 | Walltime = 5748.229
# INFO:root:[Env Loop] Episode Length = 261 | Episode Return = 28.0 | Episodes = 1096 | Steps = 192948 | Steps Per Second = 42.566
# INFO:root:[Learner] Loss = 0.274 | Steps = 23998 | Walltime = 5749.395
# INFO:root:[Learner] Loss = 0.331 | Steps = 24004 | Walltime = 5750.571
# INFO:root:[Learner] Loss = 0.236 | Steps = 24009 | Walltime = 5751.663
# INFO:root:[Learner] Loss = 0.265 | Steps = 24015 | Walltime = 5752.845
# INFO:root:[Learner] Loss = 0.235 | Steps = 24021 | Walltime = 5753.979
# INFO:root:[Env Loop] Episode Length = 253 | Episode Return = 31.0 | Episodes = 1097 | Steps = 193201 | Steps Per Second = 40.742
# INFO:root:[Learner] Loss = 0.162 | Steps = 24027 | Walltime = 5755.213
# INFO:root:[Learner] Loss = 0.174 | Steps = 24033 | Walltime = 5756.345
# INFO:root:[Learner] Loss = 0.187 | Steps = 24039 | Walltime = 5757.546
# INFO:root:[Learner] Loss = 0.160 | Steps = 24044 | Walltime = 5758.688
# INFO:root:[Learner] Loss = 0.149 | Steps = 24050 | Walltime = 5759.783
# INFO:root:[Env Loop] Episode Length = 226 | Episode Return = 25.0 | Episodes = 1098 | Steps = 193427 | Steps Per Second = 39.897
# INFO:root:[Learner] Loss = 0.233 | Steps = 24055 | Walltime = 5760.786
# INFO:root:[Learner] Loss = 0.175 | Steps = 24060 | Walltime = 5761.804
# INFO:root:[Learner] Loss = 0.251 | Steps = 24066 | Walltime = 5762.929
# INFO:root:[Learner] Loss = 0.169 | Steps = 24072 | Walltime = 5764.037
# INFO:root:[Learner] Loss = 0.150 | Steps = 24078 | Walltime = 5765.119
# INFO:root:[Env Loop] Episode Length = 234 | Episode Return = 30.0 | Episodes = 1099 | Steps = 193661 | Steps Per Second = 42.237
# INFO:root:[Learner] Loss = 0.235 | Steps = 24084 | Walltime = 5766.326
# INFO:root:[Learner] Loss = 0.213 | Steps = 24090 | Walltime = 5767.436
# INFO:root:[Learner] Loss = 0.225 | Steps = 24096 | Walltime = 5768.470
# INFO:root:[Learner] Loss = 0.201 | Steps = 24102 | Walltime = 5769.714
# INFO:root:[Learner] Loss = 0.198 | Steps = 24107 | Walltime = 5770.725
# INFO:root:[Learner] Loss = 0.240 | Steps = 24113 | Walltime = 5771.878
# INFO:root:[Env Loop] Episode Length = 257 | Episode Return = 33.0 | Episodes = 1100 | Steps = 193918 | Steps Per Second = 42.097
# INFO:root:[Learner] Loss = 0.200 | Steps = 24119 | Walltime = 5772.910
# INFO:root:[Learner] Loss = 0.316 | Steps = 24125 | Walltime = 5774.129
# INFO:root:[Learner] Loss = 0.173 | Steps = 24130 | Walltime = 5775.188
# INFO:root:[Learner] Loss = 0.133 | Steps = 24136 | Walltime = 5776.272
# INFO:root:[Learner] Loss = 0.195 | Steps = 24142 | Walltime = 5777.321
# INFO:root:[Learner] Loss = 0.291 | Steps = 24148 | Walltime = 5778.432
# INFO:root:[Learner] Loss = 0.215 | Steps = 24154 | Walltime = 5779.593
# INFO:root:[Env Loop] Episode Length = 308 | Episode Return = 23.0 | Episodes = 1101 | Steps = 194226 | Steps Per Second = 41.827
# INFO:root:[Learner] Loss = 0.247 | Steps = 24159 | Walltime = 5780.640
# INFO:root:[Learner] Loss = 0.279 | Steps = 24165 | Walltime = 5781.741
# INFO:root:[Learner] Loss = 0.208 | Steps = 24171 | Walltime = 5782.922
# INFO:root:[Learner] Loss = 0.305 | Steps = 24177 | Walltime = 5784.063
# INFO:root:[Learner] Loss = 0.260 | Steps = 24182 | Walltime = 5785.098
# INFO:root:[Learner] Loss = 0.162 | Steps = 24187 | Walltime = 5786.289
# INFO:root:[Env Loop] Episode Length = 297 | Episode Return = 29.0 | Episodes = 1102 | Steps = 194523 | Steps Per Second = 40.209
# INFO:root:[Learner] Loss = 0.197 | Steps = 24193 | Walltime = 5787.395
# INFO:root:[Learner] Loss = 0.136 | Steps = 24198 | Walltime = 5788.411
# INFO:root:[Learner] Loss = 0.314 | Steps = 24203 | Walltime = 5789.445
# INFO:root:[Learner] Loss = 0.215 | Steps = 24209 | Walltime = 5790.560
# INFO:root:[Learner] Loss = 0.184 | Steps = 24215 | Walltime = 5791.705
# INFO:root:[Learner] Loss = 0.162 | Steps = 24221 | Walltime = 5792.880
# INFO:root:[Env Loop] Episode Length = 269 | Episode Return = 36.0 | Episodes = 1103 | Steps = 194792 | Steps Per Second = 40.675
# INFO:root:[Learner] Loss = 0.213 | Steps = 24227 | Walltime = 5794.083
# INFO:root:[Learner] Loss = 0.171 | Steps = 24233 | Walltime = 5795.228
# INFO:root:[Learner] Loss = 0.275 | Steps = 24238 | Walltime = 5796.250
# INFO:root:[Learner] Loss = 0.225 | Steps = 24244 | Walltime = 5797.441
# INFO:root:[Learner] Loss = 0.206 | Steps = 24250 | Walltime = 5798.658
# INFO:root:[Learner] Loss = 0.294 | Steps = 24256 | Walltime = 5799.800
# INFO:root:[Learner] Loss = 0.187 | Steps = 24262 | Walltime = 5800.985
# INFO:root:[Env Loop] Episode Length = 328 | Episode Return = 38.0 | Episodes = 1104 | Steps = 195120 | Steps Per Second = 40.362
# INFO:root:[Learner] Loss = 0.168 | Steps = 24267 | Walltime = 5802.033
# INFO:root:[Learner] Loss = 0.219 | Steps = 24273 | Walltime = 5803.114
# INFO:root:[Learner] Loss = 0.233 | Steps = 24279 | Walltime = 5804.298
# INFO:root:[Learner] Loss = 0.158 | Steps = 24285 | Walltime = 5805.442
# INFO:root:[Learner] Loss = 0.167 | Steps = 24291 | Walltime = 5806.520
# INFO:root:[Learner] Loss = 0.188 | Steps = 24296 | Walltime = 5807.534
# INFO:root:[Env Loop] Episode Length = 256 | Episode Return = 39.0 | Episodes = 1105 | Steps = 195376 | Steps Per Second = 41.392
# INFO:root:[Learner] Loss = 0.265 | Steps = 24302 | Walltime = 5808.653
# INFO:root:[Learner] Loss = 0.185 | Steps = 24308 | Walltime = 5809.824
# INFO:root:[Learner] Loss = 0.237 | Steps = 24313 | Walltime = 5810.839
# INFO:root:[Learner] Loss = 0.222 | Steps = 24319 | Walltime = 5811.988
# INFO:root:[Env Loop] Episode Length = 170 | Episode Return = 21.0 | Episodes = 1106 | Steps = 195546 | Steps Per Second = 41.759
# INFO:root:[Learner] Loss = 0.236 | Steps = 24324 | Walltime = 5813.073
# INFO:root:[Learner] Loss = 0.188 | Steps = 24330 | Walltime = 5814.268
# INFO:root:[Learner] Loss = 0.176 | Steps = 24335 | Walltime = 5815.427
# INFO:root:[Learner] Loss = 0.182 | Steps = 24341 | Walltime = 5816.481
# INFO:root:[Learner] Loss = 0.115 | Steps = 24346 | Walltime = 5817.493
# INFO:root:[Env Loop] Episode Length = 231 | Episode Return = 29.0 | Episodes = 1107 | Steps = 195777 | Steps Per Second = 39.007
# INFO:root:[Learner] Loss = 0.207 | Steps = 24351 | Walltime = 5818.581
# INFO:root:[Learner] Loss = 0.233 | Steps = 24357 | Walltime = 5819.768
# INFO:root:[Learner] Loss = 0.191 | Steps = 24363 | Walltime = 5820.988
# ...
# INFO:root:[Learner] Loss = 0.235 | Steps = 33545 | Walltime = 7591.939
# INFO:root:[Learner] Loss = 0.157 | Steps = 33552 | Walltime = 7593.072
# INFO:root:[Env Loop] Episode Length = 229 | Episode Return = 24.0 | Episodes = 1461 | Steps = 269440 | Steps Per Second = 46.690
# INFO:root:[Learner] Loss = 0.224 | Steps = 33558 | Walltime = 7594.168
# INFO:root:[Learner] Loss = 0.292 | Steps = 33564 | Walltime = 7595.209
# INFO:root:[Learner] Loss = 0.205 | Steps = 33570 | Walltime = 7596.427
# INFO:root:[Learner] Loss = 0.173 | Steps = 33576 | Walltime = 7597.522
# INFO:root:[Env Loop] Episode Length = 190 | Episode Return = 17.0 | Episodes = 1462 | Steps = 269630 | Steps Per Second = 43.936
# INFO:root:[Learner] Loss = 0.242 | Steps = 33582 | Walltime = 7598.591
# INFO:root:[Learner] Loss = 0.290 | Steps = 33587 | Walltime = 7599.604
# INFO:root:[Learner] Loss = 0.260 | Steps = 33593 | Walltime = 7600.678
# INFO:root:[Learner] Loss = 0.304 | Steps = 33599 | Walltime = 7601.871
# INFO:root:[Env Loop] Episode Length = 201 | Episode Return = 24.0 | Episodes = 1463 | Steps = 269831 | Steps Per Second = 41.858
# INFO:root:[Learner] Loss = 0.193 | Steps = 33605 | Walltime = 7603.039
# INFO:root:[Learner] Loss = 0.266 | Steps = 33611 | Walltime = 7604.075
# INFO:root:[Learner] Loss = 0.279 | Steps = 33618 | Walltime = 7605.212
# INFO:root:[Learner] Loss = 0.273 | Steps = 33624 | Walltime = 7606.292
# INFO:root:[Env Loop] Episode Length = 154 | Episode Return = 12.0 | Episodes = 1464 | Steps = 269985 | Steps Per Second = 45.511
# INFO:root:[Learner] Loss = 0.234 | Steps = 33630 | Walltime = 7607.376
# INFO:root:[Learner] Loss = 0.199 | Steps = 33637 | Walltime = 7608.530
# INFO:root:[Env Loop] Episode Length = 148 | Episode Return = 13.0 | Episodes = 1465 | Steps = 270133 | Steps Per Second = 46.807
# INFO:root:[Learner] Loss = 0.187 | Steps = 33643 | Walltime = 7609.597
# INFO:root:[Learner] Loss = 0.294 | Steps = 33649 | Walltime = 7610.613
# INFO:root:[Learner] Loss = 0.124 | Steps = 33656 | Walltime = 7611.676
# INFO:root:[Learner] Loss = 0.244 | Steps = 33663 | Walltime = 7612.813
# INFO:root:[Learner] Loss = 0.315 | Steps = 33668 | Walltime = 7613.847
# INFO:root:[Env Loop] Episode Length = 228 | Episode Return = 35.0 | Episodes = 1466 | Steps = 270361 | Steps Per Second = 45.943
# INFO:root:[Learner] Loss = 0.203 | Steps = 33674 | Walltime = 7615.008
# INFO:root:[Env Loop] Episode Length = 66 | Episode Return = 4.0 | Episodes = 1467 | Steps = 270427 | Steps Per Second = 45.414
# INFO:root:[Learner] Loss = 0.271 | Steps = 33680 | Walltime = 7616.106
# INFO:root:[Learner] Loss = 0.286 | Steps = 33686 | Walltime = 7617.208
# INFO:root:[Learner] Loss = 0.212 | Steps = 33692 | Walltime = 7618.281
# INFO:root:[Learner] Loss = 0.284 | Steps = 33699 | Walltime = 7619.419
# INFO:root:[Learner] Loss = 0.333 | Steps = 33705 | Walltime = 7620.571
# INFO:root:[Env Loop] Episode Length = 229 | Episode Return = 15.0 | Episodes = 1468 | Steps = 270656 | Steps Per Second = 44.310
# INFO:root:[Learner] Loss = 0.281 | Steps = 33711 | Walltime = 7621.611
# INFO:root:[Learner] Loss = 0.180 | Steps = 33717 | Walltime = 7622.653
# INFO:root:[Learner] Loss = 0.196 | Steps = 33724 | Walltime = 7623.806
# INFO:root:[Learner] Loss = 0.166 | Steps = 33730 | Walltime = 7624.899
# INFO:root:[Env Loop] Episode Length = 200 | Episode Return = 13.0 | Episodes = 1469 | Steps = 270856 | Steps Per Second = 45.881
# INFO:root:[Learner] Loss = 0.226 | Steps = 33736 | Walltime = 7625.945
# INFO:root:[Learner] Loss = 0.206 | Steps = 33742 | Walltime = 7627.015
# INFO:root:[Learner] Loss = 0.283 | Steps = 33748 | Walltime = 7628.175
# INFO:root:[Env Loop] Episode Length = 135 | Episode Return = 11.0 | Episodes = 1470 | Steps = 270991 | Steps Per Second = 44.760
# INFO:root:[Learner] Loss = 0.226 | Steps = 33755 | Walltime = 7629.267
# INFO:root:[Learner] Loss = 0.252 | Steps = 33761 | Walltime = 7630.353
# INFO:root:[Learner] Loss = 0.226 | Steps = 33767 | Walltime = 7631.515
# INFO:root:[Learner] Loss = 0.275 | Steps = 33772 | Walltime = 7632.547
# INFO:root:[Learner] Loss = 0.257 | Steps = 33778 | Walltime = 7633.695
# INFO:root:[Env Loop] Episode Length = 230 | Episode Return = 29.0 | Episodes = 1471 | Steps = 271221 | Steps Per Second = 43.131
# INFO:root:[Learner] Loss = 0.262 | Steps = 33784 | Walltime = 7634.782
# INFO:root:[Learner] Loss = 0.287 | Steps = 33790 | Walltime = 7635.904
# INFO:root:[Env Loop] Episode Length = 124 | Episode Return = 10.0 | Episodes = 1472 | Steps = 271345 | Steps Per Second = 42.567
# INFO:root:[Learner] Loss = 0.232 | Steps = 33795 | Walltime = 7636.908
# INFO:root:[Learner] Loss = 0.300 | Steps = 33802 | Walltime = 7637.990
# INFO:root:[Learner] Loss = 0.208 | Steps = 33808 | Walltime = 7639.018
# INFO:root:[Learner] Loss = 0.225 | Steps = 33814 | Walltime = 7640.064
# INFO:root:[Learner] Loss = 0.215 | Steps = 33821 | Walltime = 7641.234
# INFO:root:[Learner] Loss = 0.173 | Steps = 33827 | Walltime = 7642.347
# INFO:root:[Env Loop] Episode Length = 270 | Episode Return = 39.0 | Episodes = 1473 | Steps = 271615 | Steps Per Second = 47.081
# INFO:root:[Learner] Loss = 0.155 | Steps = 33833 | Walltime = 7643.515
# INFO:root:[Learner] Loss = 0.246 | Steps = 33839 | Walltime = 7644.551
# INFO:root:[Learner] Loss = 0.214 | Steps = 33845 | Walltime = 7645.724
# INFO:root:[Env Loop] Episode Length = 158 | Episode Return = 24.0 | Episodes = 1474 | Steps = 271773 | Steps Per Second = 42.683
# INFO:root:[Learner] Loss = 0.171 | Steps = 33851 | Walltime = 7646.739
# INFO:root:[Learner] Loss = 0.332 | Steps = 33858 | Walltime = 7647.813
# INFO:root:[Learner] Loss = 0.172 | Steps = 33864 | Walltime = 7648.863
# INFO:root:[Env Loop] Episode Length = 133 | Episode Return = 11.0 | Episodes = 1475 | Steps = 271906 | Steps Per Second = 48.507
# INFO:root:[Learner] Loss = 0.287 | Steps = 33870 | Walltime = 7649.943
# INFO:root:[Learner] Loss = 0.164 | Steps = 33876 | Walltime = 7651.172
# INFO:root:[Learner] Loss = 0.287 | Steps = 33882 | Walltime = 7652.299
# INFO:root:[Learner] Loss = 0.181 | Steps = 33889 | Walltime = 7653.474
# INFO:root:[Env Loop] Episode Length = 237 | Episode Return = 30.0 | Episodes = 1476 | Steps = 272143 | Steps Per Second = 44.394
# INFO:root:[Learner] Loss = 0.330 | Steps = 33895 | Walltime = 7654.530
# INFO:root:[Learner] Loss = 0.259 | Steps = 33901 | Walltime = 7655.570
# INFO:root:[Learner] Loss = 0.257 | Steps = 33907 | Walltime = 7656.660
# INFO:root:[Env Loop] Episode Length = 152 | Episode Return = 16.0 | Episodes = 1477 | Steps = 272295 | Steps Per Second = 45.602
# INFO:root:[Learner] Loss = 0.214 | Steps = 33913 | Walltime = 7657.679
# INFO:root:[Learner] Loss = 0.279 | Steps = 33918 | Walltime = 7658.735
# INFO:root:[Learner] Loss = 0.222 | Steps = 33925 | Walltime = 7659.897
# INFO:root:[Learner] Loss = 0.156 | Steps = 33931 | Walltime = 7660.982
# INFO:root:[Learner] Loss = 0.226 | Steps = 33937 | Walltime = 7662.134
# INFO:root:[Learner] Loss = 0.227 | Steps = 33944 | Walltime = 7663.272
# INFO:root:[Learner] Loss = 0.204 | Steps = 33949 | Walltime = 7664.307
# INFO:root:[Env Loop] Episode Length = 291 | Episode Return = 44.0 | Episodes = 1478 | Steps = 272586 | Steps Per Second = 43.074
# INFO:root:[Learner] Loss = 0.234 | Steps = 33955 | Walltime = 7665.321
# INFO:root:[Learner] Loss = 0.169 | Steps = 33961 | Walltime = 7666.350
# INFO:root:[Learner] Loss = 0.228 | Steps = 33967 | Walltime = 7667.377
# INFO:root:[Env Loop] Episode Length = 173 | Episode Return = 16.0 | Episodes = 1479 | Steps = 272759 | Steps Per Second = 48.058
# INFO:root:[Learner] Loss = 0.141 | Steps = 33974 | Walltime = 7668.504
# INFO:root:[Learner] Loss = 0.286 | Steps = 33980 | Walltime = 7669.576
# INFO:root:[Learner] Loss = 0.183 | Steps = 33986 | Walltime = 7670.621
# INFO:root:[Learner] Loss = 0.215 | Steps = 33992 | Walltime = 7671.752
# INFO:root:[Env Loop] Episode Length = 195 | Episode Return = 21.0 | Episodes = 1480 | Steps = 272954 | Steps Per Second = 45.175
# INFO:root:[Learner] Loss = 0.133 | Steps = 33999 | Walltime = 7672.887
# INFO:root:[Learner] Loss = 0.238 | Steps = 34005 | Walltime = 7673.912
# INFO:root:[Learner] Loss = 0.201 | Steps = 34012 | Walltime = 7674.979
# INFO:root:[Learner] Loss = 0.316 | Steps = 34018 | Walltime = 7675.988
# INFO:root:[Env Loop] Episode Length = 188 | Episode Return = 20.0 | Episodes = 1481 | Steps = 273142 | Steps Per Second = 49.261
# INFO:root:[Learner] Loss = 0.256 | Steps = 34024 | Walltime = 7677.128
# INFO:root:[Learner] Loss = 0.168 | Steps = 34030 | Walltime = 7678.140
# INFO:root:[Learner] Loss = 0.185 | Steps = 34036 | Walltime = 7679.264
# INFO:root:[Env Loop] Episode Length = 156 | Episode Return = 16.0 | Episodes = 1482 | Steps = 273298 | Steps Per Second = 43.942
# INFO:root:[Learner] Loss = 0.196 | Steps = 34042 | Walltime = 7680.318
# INFO:root:[Learner] Loss = 0.227 | Steps = 34048 | Walltime = 7681.449
# INFO:root:[Learner] Loss = 0.358 | Steps = 34055 | Walltime = 7682.571
# INFO:root:[Learner] Loss = 0.269 | Steps = 34061 | Walltime = 7683.604
# INFO:root:[Env Loop] Episode Length = 192 | Episode Return = 24.0 | Episodes = 1483 | Steps = 273490 | Steps Per Second = 46.481
# INFO:root:[Learner] Loss = 0.234 | Steps = 34066 | Walltime = 7684.629
# INFO:root:[Env Loop] Episode Length = 64 | Episode Return = 4.0 | Episodes = 1484 | Steps = 273554 | Steps Per Second = 42.034
# INFO:root:[Learner] Loss = 0.225 | Steps = 34072 | Walltime = 7685.705
# INFO:root:[Learner] Loss = 0.223 | Steps = 34078 | Walltime = 7686.822
# INFO:root:[Learner] Loss = 0.220 | Steps = 34084 | Walltime = 7687.908
# INFO:root:[Env Loop] Episode Length = 117 | Episode Return = 9.0 | Episodes = 1485 | Steps = 273671 | Steps Per Second = 43.374
# INFO:root:[Learner] Loss = 0.257 | Steps = 34090 | Walltime = 7688.916
# INFO:root:[Learner] Loss = 0.185 | Steps = 34096 | Walltime = 7690.065
# INFO:root:[Learner] Loss = 0.144 | Steps = 34101 | Walltime = 7691.173
# INFO:root:[Learner] Loss = 0.242 | Steps = 34107 | Walltime = 7692.295
# INFO:root:[Learner] Loss = 0.190 | Steps = 34113 | Walltime = 7693.443
# INFO:root:[Env Loop] Episode Length = 237 | Episode Return = 28.0 | Episodes = 1486 | Steps = 273908 | Steps Per Second = 41.855
# INFO:root:[Learner] Loss = 0.272 | Steps = 34119 | Walltime = 7694.629
# INFO:root:[Learner] Loss = 0.139 | Steps = 34125 | Walltime = 7695.726
# INFO:root:[Learner] Loss = 0.289 | Steps = 34131 | Walltime = 7696.741
# INFO:root:[Learner] Loss = 0.187 | Steps = 34137 | Walltime = 7697.754
# INFO:root:[Env Loop] Episode Length = 220 | Episode Return = 30.0 | Episodes = 1487 | Steps = 274128 | Steps Per Second = 45.026
# INFO:root:[Learner] Loss = 0.204 | Steps = 34143 | Walltime = 7698.796
# INFO:root:[Learner] Loss = 0.163 | Steps = 34149 | Walltime = 7699.851
# INFO:root:[Learner] Loss = 0.280 | Steps = 34155 | Walltime = 7700.987
# INFO:root:[Learner] Loss = 0.226 | Steps = 34161 | Walltime = 7701.990
# INFO:root:[Learner] Loss = 0.256 | Steps = 34167 | Walltime = 7703.056
# INFO:root:[Env Loop] Episode Length = 214 | Episode Return = 22.0 | Episodes = 1488 | Steps = 274342 | Steps Per Second = 45.148
# INFO:root:[Learner] Loss = 0.196 | Steps = 34173 | Walltime = 7704.122
# INFO:root:[Learner] Loss = 0.193 | Steps = 34179 | Walltime = 7705.235
# INFO:root:[Learner] Loss = 0.250 | Steps = 34185 | Walltime = 7706.402
# INFO:root:[Learner] Loss = 0.190 | Steps = 34191 | Walltime = 7707.487
# INFO:root:[Env Loop] Episode Length = 196 | Episode Return = 25.0 | Episodes = 1489 | Steps = 274538 | Steps Per Second = 42.929
# INFO:root:[Learner] Loss = 0.212 | Steps = 34197 | Walltime = 7708.627
# INFO:root:[Learner] Loss = 0.228 | Steps = 34203 | Walltime = 7709.749
# INFO:root:[Env Loop] Episode Length = 123 | Episode Return = 11.0 | Episodes = 1490 | Steps = 274661 | Steps Per Second = 42.368
# INFO:root:[Learner] Loss = 0.266 | Steps = 34209 | Walltime = 7710.934
# INFO:root:[Learner] Loss = 0.189 | Steps = 34216 | Walltime = 7712.148
# INFO:root:[Learner] Loss = 0.204 | Steps = 34222 | Walltime = 7713.261
# INFO:root:[Env Loop] Episode Length = 148 | Episode Return = 12.0 | Episodes = 1491 | Steps = 274809 | Steps Per Second = 44.382
# INFO:root:[Learner] Loss = 0.154 | Steps = 34228 | Walltime = 7714.338
# INFO:root:[Learner] Loss = 0.323 | Steps = 34234 | Walltime = 7715.411
# INFO:root:[Learner] Loss = 0.288 | Steps = 34240 | Walltime = 7716.501
# INFO:root:[Env Loop] Episode Length = 144 | Episode Return = 14.0 | Episodes = 1492 | Steps = 274953 | Steps Per Second = 43.750
# INFO:root:[Learner] Loss = 0.218 | Steps = 34246 | Walltime = 7717.642
# INFO:root:[Learner] Loss = 0.267 | Steps = 34252 | Walltime = 7718.780
# INFO:root:[Learner] Loss = 0.267 | Steps = 34257 | Walltime = 7719.839
# INFO:root:[Learner] Loss = 0.120 | Steps = 34263 | Walltime = 7720.995
# INFO:root:[Learner] Loss = 0.224 | Steps = 34269 | Walltime = 7722.111
# INFO:root:[Env Loop] Episode Length = 215 | Episode Return = 32.0 | Episodes = 1493 | Steps = 275168 | Steps Per Second = 41.043
# INFO:root:[Learner] Loss = 0.185 | Steps = 34275 | Walltime = 7723.297
# INFO:root:[Learner] Loss = 0.329 | Steps = 34281 | Walltime = 7724.463
# INFO:root:[Learner] Loss = 0.230 | Steps = 34287 | Walltime = 7725.515
# INFO:root:[Learner] Loss = 0.277 | Steps = 34293 | Walltime = 7726.559
# INFO:root:[Learner] Loss = 0.233 | Steps = 34298 | Walltime = 7727.566
# INFO:root:[Env Loop] Episode Length = 208 | Episode Return = 27.0 | Episodes = 1494 | Steps = 275376 | Steps Per Second = 42.658
# INFO:root:[Learner] Loss = 0.230 | Steps = 34303 | Walltime = 7728.580
# INFO:root:[Learner] Loss = 0.240 | Steps = 34309 | Walltime = 7729.726
# INFO:root:[Learner] Loss = 0.225 | Steps = 34315 | Walltime = 7730.843
# INFO:root:[Learner] Loss = 0.194 | Steps = 34321 | Walltime = 7732.000
# INFO:root:[Env Loop] Episode Length = 210 | Episode Return = 22.0 | Episodes = 1495 | Steps = 275586 | Steps Per Second = 41.772
# INFO:root:[Learner] Loss = 0.216 | Steps = 34327 | Walltime = 7733.140
# INFO:root:[Learner] Loss = 0.233 | Steps = 34333 | Walltime = 7734.154
# INFO:root:[Learner] Loss = 0.226 | Steps = 34339 | Walltime = 7735.316
# INFO:root:[Learner] Loss = 0.267 | Steps = 34344 | Walltime = 7736.322
# INFO:root:[Learner] Loss = 0.263 | Steps = 34349 | Walltime = 7737.349
# INFO:root:[Env Loop] Episode Length = 241 | Episode Return = 28.0 | Episodes = 1496 | Steps = 275827 | Steps Per Second = 41.572
# INFO:root:[Learner] Loss = 0.263 | Steps = 34355 | Walltime = 7738.583
# INFO:root:[Learner] Loss = 0.187 | Steps = 34361 | Walltime = 7739.718
# INFO:root:[Learner] Loss = 0.247 | Steps = 34367 | Walltime = 7740.820
# INFO:root:[Learner] Loss = 0.162 | Steps = 34373 | Walltime = 7742.021
# INFO:root:[Learner] Loss = 0.240 | Steps = 34379 | Walltime = 7743.083
# INFO:root:[Learner] Loss = 0.218 | Steps = 34385 | Walltime = 7744.122
# INFO:root:[Env Loop] Episode Length = 262 | Episode Return = 32.0 | Episodes = 1497 | Steps = 276089 | Steps Per Second = 43.036
# INFO:root:[Learner] Loss = 0.284 | Steps = 34391 | Walltime = 7745.173
# INFO:root:[Learner] Loss = 0.237 | Steps = 34397 | Walltime = 7746.253
# INFO:root:[Learner] Loss = 0.222 | Steps = 34403 | Walltime = 7747.305
# INFO:root:[Env Loop] Episode Length = 147 | Episode Return = 16.0 | Episodes = 1498 | Steps = 276236 | Steps Per Second = 45.498
# INFO:root:[Learner] Loss = 0.190 | Steps = 34409 | Walltime = 7748.388
# INFO:root:[Learner] Loss = 0.214 | Steps = 34415 | Walltime = 7749.576
# INFO:root:[Learner] Loss = 0.269 | Steps = 34421 | Walltime = 7750.748
# INFO:root:[Learner] Loss = 0.237 | Steps = 34427 | Walltime = 7751.877
# INFO:root:[Learner] Loss = 0.203 | Steps = 34434 | Walltime = 7753.043
# INFO:root:[Env Loop] Episode Length = 231 | Episode Return = 26.0 | Episodes = 1499 | Steps = 276467 | Steps Per Second = 42.927
# INFO:root:[Learner] Loss = 0.139 | Steps = 34440 | Walltime = 7754.186
# INFO:root:[Learner] Loss = 0.200 | Steps = 34446 | Walltime = 7755.348
# INFO:root:[Learner] Loss = 0.270 | Steps = 34452 | Walltime = 7756.543
# INFO:root:[Learner] Loss = 0.255 | Steps = 34458 | Walltime = 7757.697
# INFO:root:[Env Loop] Episode Length = 190 | Episode Return = 22.0 | Episodes = 1500 | Steps = 276657 | Steps Per Second = 41.084

# %%
timestep = environment.reset()
frames = [render(environment)]

while not timestep.last():
  # Simple environment loop.
  action = agent.select_action(timestep.observation)
  timestep = environment.step(action)

  # Render the scene and add it to the frame stack.
  frames.append(render(environment))

# Save and display a video of the behaviour.
display_video(np.array(frames))
# Out:
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (160, 210) to (160, 224) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# <video  width="320" height="240" controls alt="test" src="data:video/mp4;base64,...">

# %%
agent

# %%
from tensorflow.saved_model import load

# %%
agent = load('/home/hayato/acme/b8ca9590-d77d-11eb-b169-332db766104b/checkpoints/dqn_learner')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-22-0ed1ae2e1619> in <module>
# ----> 1 agent = load('/home/hayato/acme/b8ca9590-d77d-11eb-b169-332db766104b/checkpoints/dqn_learner')
#
# ~/anaconda3/envs/acme/lib/python3.8/site-packages/tensorflow/python/saved_model/load.py in load(export_dir, tags, options)
#     862   """
#     863   metrics.IncrementReadApi(_LOAD_V2_LABEL)
# --> 864   result = load_internal(export_dir, tags, options)["root"]
#     865   metrics.IncrementRead()
#     866   return result
#
# ~/anaconda3/envs/acme/lib/python3.8/site-packages/tensorflow/python/saved_model/load.py in load_internal(export_dir, tags, options, loader_cls, filters)
#     876     tags = nest.flatten(tags)
#     877   saved_model_proto, debug_info = (
# --> 878       loader_impl.parse_saved_model_with_debug_info(export_dir))
#     879
#     880   if (len(saved_model_proto.meta_graphs) == 1 and
#
# ~/anaconda3/envs/acme/lib/python3.8/site-packages/tensorflow/python/saved_model/loader_impl.py in parse_saved_model_with_debug_info(export_dir)
#      58     parsed. Missing graph debug info file is fine.
#      59   """
# ---> 60   saved_model = _parse_saved_model(export_dir)
#      61
#      62   debug_info_path = os.path.join(
#
# ~/anaconda3/envs/acme/lib/python3.8/site-packages/tensorflow/python/saved_model/loader_impl.py in parse_saved_model(export_dir)
#     116       raise IOError("Cannot parse file %s: %s." % (path_to_pbtxt, str(e)))
#     117   else:
# --> 118     raise IOError(
#     119         "SavedModel file does not exist at: %s%s{%s|%s}" %
#     120         (export_dir, os.path.sep, constants.SAVED_MODEL_FILENAME_PBTXT,
#
# OSError: SavedModel file does not exist at: /home/hayato/acme/b8ca9590-d77d-11eb-b169-332db766104b/checkpoints/dqn_learner/{saved_model.pbtxt|saved_model.pb}

# %%
# agent.save('pong_model')
from acme.tf.savers import Checkpointer, Snapshotter

# %%
checkpointer = Checkpointer(objects_to_save={'model': network})

# %%
checkpointer._checkpoint_dir = '/home/hayato/acme/b8ca9590-d77d-11eb-b169-332db766104b/checkpoints/dqn_learner'

# %%
agent._checkpointer
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-496548f9ab25> in <module>
# ----> 1 agent._checkpointer
#
# AttributeError: 'Snapshot' object has no attribute '_checkpointer'

# %%
from tensorflow.train import Checkpoint

# %%
checkpointer._checkpoint_manager._latest_checkpoint = '/home/hayato/acme/b8ca9590-d77d-11eb-b169-332db766104b/checkpoints/dqn_learner'

# %%
# checkpointer = Checkpointer(objects_to_save={'model': agent})
snapshot = Snapshotter(objects_to_save={"model": network})

# %%
snapshot.save()
# Out:
# INFO:tensorflow:Assets written to: /home/hayato/acme/155dbec6-d5f4-11eb-a11b-03d440faad90/snapshots/model/assets
# INFO:tensorflow:Assets written to: /home/hayato/acme/155dbec6-d5f4-11eb-a11b-03d440faad90/snapshots/model/assets
# True
